# %%
from pymongo import MongoClient
import jieba
import jieba.analyse
word_dict = {}
emotion=[]
path="E:\\PythonWin\\workspace\\dict\\emotionDict\\"
get_emotion_dict(path)
jieba.load_userdict("E:\\PythonWin\\workspace\\dict\\moedDict\\moedict--revised.txt")
positive = 0
negative = 0
pos = []
neg = []
posSen=[]
negSen=[]
IP = 'localhost'
client = MongoClient(IP, 27017)
# Select database
db = client.test
# Select collection
collection = db.test
datas = collection.find({"brand":"Nissan"})
for idx , data in enumerate (datas):
    if idx <10:
        pos=[]
        neg=[]
        posSen=[]
        negSen=[]
        positive = 0
        negative = 0
        contents = cutSentence(data['content'])
        for content in contents:
            wdCuts = jieba.analyse.extract_tags(content)
            for wdCut in wdCuts:
                if wdCut in word_dict['positiveDict']:
                    positive +=1
                    pos.append(wdCut)
                    posSen.append(content)
                    posSen = list(set(posSen))
                elif wdCut in word_dict['negativeDict']:
                    negative +=1
                    neg.append(wdCut)
                    negSen.append(content)
                    negSen = list(set(negSen))
                else:None
        if positive > negative:print("整體輿論為正面")
        elif positive < negative:print("整體輿論為負面")
        else:print("整體輿論為中性")
        print("出現正面詞彙的段落:{}".format(posSen))
        print("出現負面詞彙的段落:{}".format(negSen))
        print("---------------------------------------------")
        print("positive keyword:{}".format(pos))
        print("negative keyword:{}".format(neg))
        print("=============================================")
# Out:
# 整體輿論為負面
# 出現正面詞彙的段落:[]
# 出現負面詞彙的段落:['只可惜只有日本才看得到']
# ---------------------------------------------
# positive keyword:[]
# negative keyword:['可惜']
# =============================================
# 整體輿論為中性
# 出現正面詞彙的段落:['好像日系車包括toyota', '是否還有其他人有聽說呢']
# 出現負面詞彙的段落:['那明年買車不就少了5萬空間', '會不會太誇張']
# ---------------------------------------------
# positive keyword:['還有', '聽說', '好像']
# negative keyword:['不會', '誇張', '不就']
# =============================================
# 整體輿論為正面
# 出現正面詞彙的段落:['😀今天去展示場去看了實車有點失望以下心得1.1.6Livina 外形 太楊春  感覺誠意不夠  只有頂級才有外包2.1.6Livina 49.9萬 跟 1.6 TIIDA 49.9  比皮椅 TIIDA 優  比空間 TIIDA 優  比組裝  TIIDA 優    比質感 TIIDA 勝  比油耗  TIIDA 勝   比折價 TIIDA 優  約3']
# 出現負面詞彙的段落:['😀今天去展示場去看了實車有點失望以下心得1.1.6Livina 外形 太楊春  感覺誠意不夠  只有頂級才有外包2.1.6Livina 49.9萬 跟 1.6 TIIDA 49.9  比皮椅 TIIDA 優  比空間 TIIDA 優  比組裝  TIIDA 優    比質感 TIIDA 勝  比油耗  TIIDA 勝   比折價 TIIDA 優  約3']
# ---------------------------------------------
# positive keyword:['感覺', '誠意']
# negative keyword:['不夠']
# =============================================
# 整體輿論為正面
# 出現正面詞彙的段落:['6.加滿油以上63.9萬', '板上如果有更優點的單', '如果以目前1.8L規的單來看這無疑是超級大肥單但Nissan新車剛上市', '防水托盤.避光墊.引擎平衡拉桿.....業務表示', '保險.動保.領牌 實報實銷還有很多常見的配備 例', '謝謝', '這兩個是我比較想要的', '也許需等廠商開模.量身訂做吧', '連力巨人和LED後照鏡 也沒有 ']
# 出現負面詞彙的段落:['故還沒有配件', '不知道這個單如何可以需再多談些什麼配備嗎']
# ---------------------------------------------
# positive keyword:['以上', '還有', '常見', '很多', '防水', '平衡', '表示', '也許', '巨人', '想要', '無疑', '超級', '優點', '謝謝']
# negative keyword:['還沒有', '不知道']
# =============================================
# 整體輿論為正面
# 出現正面詞彙的段落:['贈送配備', '因為第一次買車 不知道能否下訂', '煩請各位高手們給予指教 謝謝']
# 出現負面詞彙的段落:['32.8 頭款', '因為第一次買車 不知道能否下訂']
# ---------------------------------------------
# positive keyword:['第一次', '給予', '謝謝', '高手', '贈送']
# negative keyword:['不知道', '頭款']
# =============================================
# 整體輿論為中性
# 出現正面詞彙的段落:[]
# 出現負面詞彙的段落:[]
# ---------------------------------------------
# positive keyword:[]
# negative keyword:[]
# =============================================
# 整體輿論為正面
# 出現正面詞彙的段落:['3.海馬防水腳踏墊', '附帶條件是保險一定要給他們保', '11.防水托盤', '8.力巨人排檔鎖', '請問還有空間嗎', '因為也是公司收入來源......', '謝謝', '以上55.5 萬現金價 OR 30萬30期']
# 出現負面詞彙的段落:['不用分期沒有比較便宜....']
# ---------------------------------------------
# positive keyword:['防水', '巨人', '防水', '以上', '一定', '也是', '收入', '還有', '謝謝']
# negative keyword:['不用']
# =============================================
# 整體輿論為正面
# 出現正面詞彙的段落:['因為小弟過陣子會換到一個每天通勤上下班大概要70公里左右的路程去上班如果是以目前95市價來算的話一個月大概要4500左右油費', '還是本來就可以加了']
# 出現負面詞彙的段落:['所以想加減省點油費但重點是加92對車子本身引擎會不會有啥麼影響']
# ---------------------------------------------
# positive keyword:['大概', '還是']
# negative keyword:['不會']
# =============================================
# 整體輿論為中性
# 出現正面詞彙的段落:['還有那些地方要強化的']
# 出現負面詞彙的段落:['小弟的331\xa0\xa0想掛渦輪不知道各位的看法如何']
# ---------------------------------------------
# positive keyword:['還有']
# negative keyword:['不知道']
# =============================================
# 整體輿論為正面
# 出現正面詞彙的段落:['瓶身看了又看還是搞不太清楚問業代也是模糊不清只說是日本做的油品另外市面上所販售的機油除了中油製品外塑膠瓶裝的進口油應該都是台灣分裝應該是多了分裝費怎麼會比4L原裝鐵罐子的還要便宜', '以上請解惑...感恩']
# 出現負面詞彙的段落:['瓶身看了又看還是搞不太清楚問業代也是模糊不清只說是日本做的油品另外市面上所販售的機油除了中油製品外塑膠瓶裝的進口油應該都是台灣分裝應該是多了分裝費怎麼會比4L原裝鐵罐子的還要便宜']
# ---------------------------------------------
# positive keyword:['應該', '還是', '也是', '還要', '感恩', '以上']
# negative keyword:['怎麼會']
# =============================================

# %%
for sign in signal:
    print(sign)
# Out:
# ﻿!
# \xa5
# \xa4
# \xa3
# \xa2
# \xa1
# \xa0
# %
# $
# '
# &
# )
# (
# +
# *
# -
# /
# :
# =
# <
# ?
# >
# @
# \xc2
# #
# "
# [
# ]
# \\
# _
# ^
# `
# {
# }
# |
# ~
# –
# !!
# ?!
# ??
# !?
# `
# ``
# ''
# ,
# :
# ;
# "
# '
# <
# >
# *
# ..
# ...
# →
# ？
# ?
# ，
# 。
# ；
# ※
# ～
# ∕
# ⊙
# ＝
# ﹦
# ≠
# »
# ×
# ÷
# ∀
# ∇
# ∥
# ∩
# ∪
# ∴
# ∼
# ≒
# ≡
# ≦
# ≧
# ⋯
# ■
# □
# ▲
# △
# ▼
# ▽
# ◆
# ○
# ◎
# ●
# ↑
# →
# ☞
# ↓
# ←
# ☜
# ─
# ═
# │
# ┌
# ╭
# ┐
# ╮
# └
# ╰
# ┘
# ╯
# ┬
# ╧
# ╱
# ╳
# ▁
# ▂
# ▃
# ▄
# ▅
# ▆
# ▇
# █
# ®
# °
# ・
# ･
# ‥
# 〒
# ☆
# ★
# ☺
# ♞
# ♪
# ✌
# ❤
# •
# ︰
# ※
# <br>
# </br>

# %%
with open("E:\\PythonWin\\workspace\\dict\\uselessDict\\specialSignList.txt",'r',encoding='utf-8') as frS:
    cutWds=frS.read().strip().split('\n')
    cutlist = [cutWd for cutWd in cutWds if len(cutWd)>0]
    print(cutlist)
# Out:
# ['\ufeff!!', '!', '\\xa5', '\\xa4', '\\xa3', '\\xa2', '\\xa1', '\\xa0', '%', '$', "'", '&', ')', '(', '+', '*', '-', '/', ':', '=', '<', '?', '>', '@', '\\xc2', '#', '"', '[', ']', '\\\\', '_', '^', '`', '{', '}', '|', '~', '–', '!!', '?!', '??', '!?', '`', '``', "''", ',', ':', ';', '"', "'", '<', '>', '*', '..', '...', '→', '？', '?', '，', '。', '；', '※', '～', '∕', '⊙', '＝', '﹦', '≠', '»', '×', '÷', '∀', '∇', '∥', '∩', '∪', '∴', '∼', '≒', '≡', '≦', '≧', '⋯', '■', '□', '▲', '△', '▼', '▽', '◆', '○', '◎', '●', '↑', '→', '☞', '↓', '←', '☜', '─', '═', '│', '┌', '╭', '┐', '╮', '└', '╰', '┘', '╯', '┬', '╧', '╱', '╳', '▁', '▂', '▃', '▄', '▅', '▆', '▇', '█', '®', '°', '・', '･', '‥', '〒', '☆', '★', '☺', '♞', '♪', '✌', '❤', '•', '︰', '※', '<br>', '</br>']

# %%
def get_emotion_dict(path):
    emotionDict= ['negativeDict','positiveDict']
    for emotionWd in emotionDict:
        open_dict(path,emotionWd)   
        # print(word_dict)
    return word_dict

# %%
def open_dict(path,emotionWd):
    with open(path+emotionWd+".txt","r",encoding='utf-8') as fr:
        data=fr.read().strip().split('\n')
        dict_list = [word for word in data if len(word)>0]
        word_dict[emotionWd] = dict_list
    return word_dict

# %%
def get_brand_keyWord(column,word_dict):
    data[column] = data[column].lower().replace('-', '_')
    WdCuts = jieba.analyse.extract_tags(data[column])
    for WdCut in WdCuts:
        for key, word_list in word_dict.items():
            if WdCut in word_list:
                brand.append(key)
    return brand

# %%
def cutSentence(string):  ##放入原始文章路徑, 增加斷詞的list
    #     text = codecs.open(text_path,"r","utf-8")   #開檔 #讀取存成TXT檔的文字，讀入後統一轉成UTF-8格式
    sentence = ""
    textList = []

#     print('\n',type(string))
    # print(string)
    for word in string:
        # print(word)
        if word not in cutlist:  # 如果文字不是標點符號，就把字加到句子中
            sentence += word
            # print(sentence)
        else:
            textList.append(sentence)  # 如果遇到標點符號，把句子加到 text list中
            sentence = ""
            # print(textList)

    return textList  # 傳回一個文字陣列

# %%
with open("E:\\PythonWin\\workspace\\dict\\emotionDict\\positiveDict.txt",'r',encoding = 'utf-8') as frB:
    bad_emotions = frB.read().strip().split('\n')
    for bad_emotion in bad_emotions:
        print(bad_emotion)
# Out:
# ﻿一夕成名
# 一大步
# 一大指標
# 一大突破
# 一大勝利
# 一己之力
# 一分打點
# 一夫當關
# 一心想
# 一日千里
# 一再出現
# 一同競爭
# 一吐為快
# 一向
# 一向認為
# 一如
# 一如以往
# 一如往昔
# 一如預期
# 一字不差
# 一帆風順
# 一見鍾情
# 一併打破
# 一併移轉
# 一併通過
# 一定
# 一定可以
# 一定是
# 一定要
# 一定要像
# 一定時間
# 一定能
# 一定參加
# 一定得
# 一定程度
# 一定會
# 一定會是
# 一往情深
# 一枝獨秀
# 一爭高下
# 一直
# 一直是
# 一直堅持
# 一秉
# 一律
# 一律列入
# 一流
# 一炮而紅
# 一致
# 一致公認
# 一致支持
# 一致同意
# 一致決
# 一致決議
# 一致性
# 一致宣布
# 一致建議
# 一致看好
# 一致通過
# 一個機會
# 一席之地
# 一笑置之
# 一級棒
# 一桿進洞
# 一統
# 一統江山
# 一貫
# 一雪前恥
# 一開始
# 一意
# 一路平安
# 一路長紅
# 一路順風
# 一路過關斬將
# 一路緊咬
# 一路趕上
# 一路領先
# 一路攀升
# 一路穩健
# 一道大菜
# 一窩蜂
# 一鳴驚人
# 一樣有效
# 一樣容易
# 一盤未失
# 一線生機
# 一線曙光
# 一償宿願
# 一臂之力
# 一舉成名
# 一舉解決
# 一舉擊敗
# 一壘安打
# 一蹴可幾
# 一躍上前
# 九五之尊
# 九霄雲外
# 了不起
# 了然於心
# 了然於胸
# 了解商情
# 人山人海
# 人心所向
# 人必自重而後人重之
# 人生至樂
# 人味
# 人性
# 人格高尚
# 人氣
# 人氣天王
# 人氣王
# 人氣巨星
# 人氣高
# 人氣鼎沸
# 人情味
# 人逢喜事精神爽
# 人道精神
# 人道關懷
# 人盡皆知
# 人數眾多
# 人機璧還
# 入土為安
# 入主
# 入味
# 入神
# 入帳
# 入榜
# 八成是
# 力主
# 力求
# 力拚
# 力爭
# 力爭上游
# 力保江山
# 力促
# 力持
# 力挽狂瀾
# 力留
# 力退
# 力圖
# 力圖振作
# 力圖趕上
# 力戰
# 力邀
# 十分
# 十分方便
# 十分成功
# 十分有利
# 十分自在
# 十分壯觀
# 十分相似
# 十分重要
# 十分重視
# 十分容易
# 十分特別
# 十分神似
# 十分接近
# 十分清楚
# 十分感謝
# 十分稱職
# 十分熟悉
# 十分激烈
# 十分激賞
# 十分踴躍
# 十分簡單
# 十分關切
# 十足
# 十拿九穩
# 十勝投手
# 又有何妨
# 又有表現
# 又長又密
# 又是
# 又深又刁
# 又深又強
# 又深又猛
# 又遠又準
# 又穩又準
# 又贏了
# 三大要項
# 三分打點
# 三分全壘打
# 三分彈
# 三足鼎立
# 三度塞揚獎
# 三思而後行
# 三強林立
# 三連霸
# 三壘打
# 三贏
# 三響砲
# 下功夫
# 下定決心
# 下放
# 上上之策
# 上天之選
# 上市發行
# 上好
# 上來
# 上風
# 上陣
# 上場一搏
# 上揚
# 上等
# 上進
# 上路
# 上榜
# 上漲
# 也可
# 也可以
# 也同意
# 也有
# 也有同感
# 也很不錯
# 也是
# 也能
# 也許
# 也期盼
# 也想
# 也會
# 也應
# 千方百計
# 千呼萬喚
# 千載難逢
# 口出狂言
# 口徑一致
# 口感好
# 口頭通過
# 士氣大振
# 大一統
# 大一點
# 大刀闊斧
# 大力
# 大力支持
# 大力改善
# 大力協助
# 大力拔擢
# 大力推展
# 大力推動
# 大力敦促
# 大力發展
# 大丈夫
# 大大成功
# 大大改善
# 大方
# 大方送
# 大王
# 大出風頭
# 大出鋒頭
# 大功臣
# 大功告成
# 大名鼎鼎
# 大多一致
# 大多數
# 大好
# 大好機會
# 大收穫
# 大有可為
# 大有前途
# 大有裨益
# 大有機會
# 大有關係
# 大利多
# 大局著想
# 大快人心
# 大步
# 大步邁向
# 大步邁進
# 大事
# 大受鼓舞
# 大受歡迎
# 大和解
# 大放光芒
# 大放送
# 大放異采
# 大放異彩
# 大於
# 大門
# 大勇
# 大度
# 大很多
# 大為升高
# 大為降低
# 大為提升
# 大為解凍
# 大為興起
# 大約可推斷
# 大致
# 大致完成
# 大致底定
# 大致相同
# 大風吹
# 大展身手
# 大展虎威
# 大展商機
# 大書特書
# 大砲
# 大笑
# 大起
# 大逆轉
# 大逆轉勝
# 大將
# 大赦
# 大部分
# 大勝
# 大喜
# 大喜若狂
# 大幅上升
# 大幅上揚
# 大幅升值
# 大幅回穩
# 大幅成長
# 大幅改善
# 大幅降低
# 大幅勝出
# 大幅提升
# 大幅提振
# 大幅提高
# 大幅超越
# 大幅開放
# 大幅領先
# 大幅增加
# 大幅緩和
# 大幅縮短
# 大棒燙
# 大無畏
# 大筆
# 大量需求
# 大開
# 大黑馬
# 大勢所趨
# 大概
# 大肆慶祝
# 大團結
# 大漲
# 大增
# 大撈一票
# 大熱門
# 大篇幅
# 大獲全勝
# 大膽搶進
# 大舉介入
# 大舉投入
# 大賺
# 大賺厚利
# 大禮
# 大翻身
# 大轉折
# 大願
# 大贏家
# 大躍進
# 大權
# 大權在握
# 大顯身手
# 大顯威風
# 女王
# 小天使
# 小心謹慎
# 小有斬獲
# 小而美
# 小巫見大巫
# 小勝
# 小揚
# 小試身手
# 小賺
# 小贏
# 工整
# 已大幅改善
# 已可媲美
# 已成
# 已成了
# 已成定局
# 已有
# 已有改善
# 已利用
# 已完成
# 已找到
# 已見成效
# 已足
# 已具
# 已取得
# 已爭取到
# 已恢復
# 已研擬
# 已計畫
# 已拿到
# 已將
# 已接近
# 已接獲
# 已發行
# 已經
# 已經成為
# 已經足夠
# 已經掌握
# 已經開始
# 已經解決
# 已達
# 已達成
# 已達到
# 已慢慢穩定
# 已確定
# 已適合
# 已獲
# 已獲全面改善
# 已獲共識
# 已趨鞏固
# 弓臂一振
# 才女
# 才可
# 才有
# 才有利
# 才是
# 才氣
# 才能
# 才能真正減輕
# 才得
# 才智
# 才華
# 才幹
# 才會
# 才藝
# 不二法門
# 不凡
# 不凡的人
# 不反
# 不反對
# 不少進帳
# 不止於
# 不乏
# 不令人意外
# 不可不知
# 不可名狀
# 不可或缺
# 不可抵擋
# 不可阻撓
# 不可侵犯
# 不可限量
# 不外
# 不外乎
# 不失
# 不必擔心
# 不正是
# 不亦樂乎
# 不任性
# 不同凡響
# 不吃虧
# 不如坦誠面對
# 不成為問題
# 不成問題
# 不朽英名
# 不死
# 不老
# 不自私
# 不吝採納
# 不否認
# 不含糊
# 不妨
# 不忍
# 不言可喻
# 不亞於
# 不受約束
# 不受限制
# 不受影響
# 不屈不撓
# 不屈服
# 不怕
# 不拘泥
# 不放過
# 不爭
# 不爭的事實
# 不是軟腳蝦
# 不牴觸
# 不負
# 不迫
# 不限
# 不陌生
# 不容忽視
# 不容抹殺
# 不容推諉
# 不容損耗
# 不悔
# 不能不
# 不能不知道
# 不能不解決
# 不衰
# 不起訴
# 不偏不倚
# 不偏不倚地
# 不動搖
# 不惜
# 不推諉
# 不移
# 不訝異
# 不設限
# 不就好了
# 不就得了
# 不復舊觀
# 不惡
# 不曾失手
# 不猶豫
# 不費吹灰之力
# 不超過
# 不意外
# 不慌忙
# 不愧
# 不愧為
# 不會弄錯
# 不會受傷害
# 不會威脅
# 不會傷害
# 不會影響
# 不禁
# 不禁止
# 不禁高昂
# 不禁想起
# 不虞
# 不違
# 不違法
# 不違背
# 不調降
# 不懈
# 不諱言
# 不輸
# 不輸於
# 不遺餘力
# 不錯
# 不隱瞞
# 不斷努力
# 不斷重復
# 不斷提高
# 不斷鼓吹
# 不斷遞增
# 不斷擴散
# 不難
# 不難理解
# 中心支柱
# 中方有充分證據
# 中和
# 中肯
# 丰采
# 丰采依舊
# 丰姿
# 之上
# 之首
# 之賜
# 予以
# 予以支持
# 予以保護
# 予以配合
# 予以規範
# 予以補助
# 予保護
# 井然有序
# 互不侵犯
# 互有領先
# 互別苗頭
# 互利
# 互助
# 互助合作
# 互信
# 互保
# 互為刺激
# 互相合作
# 互相安慰
# 互相妥協
# 互相密合著
# 互相連繫
# 互相結合
# 互動
# 互動頻繁
# 互訪
# 互設
# 互惠
# 互惠互助
# 互敬
# 互補
# 互蒙其利
# 互讓
# 仁善
# 仁慈
# 仍可
# 仍可以
# 仍未改變
# 仍由
# 仍在調查
# 仍有
# 仍有可能
# 仍有成長
# 仍有希望
# 仍有意
# 仍作
# 仍希望
# 仍依
# 仍依賴
# 仍佳
# 仍待
# 仍持
# 仍持續
# 仍是
# 仍為可行
# 仍能
# 仍將
# 仍將是
# 仍得
# 仍得辦
# 仍採
# 仍被看好
# 仍然
# 仍然存在
# 仍進行
# 仍須
# 仍會
# 仍會維持
# 仍需
# 仍適用
# 仍應
# 仍應保留
# 仍獲
# 仍獲好評
# 仍獲青睞
# 今起展開
# 介紹
# 允許
# 允當
# 允諾
# 允諾了
# 內行
# 內斂
# 公允
# 公布
# 公平
# 公平正義
# 公平地
# 公正
# 公正地
# 公正客觀
# 公佈
# 公告
# 公決
# 公信力
# 公開
# 公義
# 公認
# 公諸
# 分久必合
# 分寸
# 分工
# 分工合作
# 分工更具體
# 分不開
# 分享
# 分庭亢禮
# 分庭抗禮
# 分散風險
# 分發
# 分擔
# 切合
# 切實
# 切實執行
# 切題
# 勻稱
# 勿忘
# 化干戈為玉帛
# 化為真實
# 化被動為主動
# 化暗為明
# 化解
# 化解危機
# 化解歧見
# 化解阻力
# 化敵為友
# 化險為夷
# 匹敵
# 升至
# 升到
# 升為
# 升值
# 升格
# 升級
# 升級相當明顯
# 升起
# 升高
# 升勢
# 友好
# 友好合作
# 友善
# 友愛
# 及早因應
# 及早回頭
# 及早確定
# 及時
# 及時回魂
# 及時修正
# 及時掌握
# 及時調整
# 及時穩住
# 及格
# 及得上
# 反反
# 反以
# 反映
# 反映輿情
# 反敗為勝
# 反蒙其利
# 反應很好
# 反應熱烈
# 反覆強調
# 天才
# 天才人物
# 天不會塌下來
# 天分
# 天文數字
# 天文數字般
# 天王
# 天王巨星
# 天生好手
# 天后
# 天后級
# 天作之合
# 天使
# 天使般的人
# 天真
# 天真的信賴
# 天真無邪
# 天堂
# 天資
# 天資聰明
# 天賦
# 天縱英才
# 天籟
# 太平盛世
# 太在意
# 太好
# 太好了
# 太好過
# 太快
# 太突出
# 太重視
# 太高
# 太高興
# 太強
# 太猛了
# 太棒
# 太驚人
# 少人能及
# 少壯
# 尤其
# 尤其是
# 尤其高
# 尤物
# 尤甚
# 尤值注意
# 尤勝
# 尤然
# 引人入勝
# 引人注意
# 引人猜測
# 引人關注
# 引人讚美
# 引人讚美的人
# 引以為傲
# 引以為榮
# 引以為榮的事物
# 引用
# 引申
# 引吭
# 引吭高歌
# 引來
# 引為殷鑒
# 引述
# 引起騷動
# 引領而望
# 引據
# 引頸企盼
# 心心相印
# 心平氣和
# 心如止水
# 心安
# 心安理得
# 心有戚戚
# 心有靈犀
# 心服
# 心服口服
# 心花怒放
# 心動
# 心情愉快
# 心情舒暢
# 心細
# 心喜
# 心無畏懼
# 心意
# 心想事成
# 心愛
# 心誠則靈
# 心滿意足
# 心滿意足地注視
# 心儀
# 心寬
# 心寬體胖
# 心醉
# 心醉神迷
# 心聲
# 心曠神怡
# 心繫百姓
# 心願
# 手到擒來
# 手風奇順
# 手牽手
# 手藝
# 支助
# 支持
# 支持力量
# 支持者
# 支柱
# 支配性
# 支撐
# 支應
# 文明
# 文雅
# 斗膽
# 方便
# 方能
# 方得
# 日久生情
# 日益凸顯
# 日益明顯
# 日益精良
# 日益增多
# 日漸成熟
# 日漸茁壯
# 日增
# 日臻完善
# 日趨重要
# 日趨密切
# 日趨濃厚
# 日趨擴大
# 止痛
# 止跌回升
# 毋寧
# 毋寧是
# 比以往高
# 比他好
# 比率為最高
# 比率較高
# 比照
# 比較可能
# 比較好
# 比較便宜
# 比預期好
# 比數差距最大
# 水平
# 水準
# 水準相當
# 水準最高
# 水落石出
# 水漲船高
# 火力
# 火力大發
# 火力支援
# 火力旺盛
# 火力齊發
# 火速
# 火速通過
# 牛刀小試
# 牛耳
# 王子
# 王中王
# 王見王
# 王者
# 王國
# 王朝
# 王牌
# 世所矚目
# 世界冠軍
# 世界排名第一球員
# 世界排名這麼高
# 世界排名這麼高的選手
# 世界球王
# 世界第一
# 丕變
# 主角
# 主持
# 主持協商
# 主要
# 主要功臣
# 主要考驗
# 主要的辯
# 主要是
# 主要尋求
# 主要意義
# 主宰
# 主宰力
# 主動
# 主動出擊
# 主動回收
# 主動協助
# 主動協調
# 主動建立
# 主動連繫
# 主動提供
# 主動幫忙
# 主張
# 主控
# 主控權
# 主場優勢
# 主導地位
# 主導優勢
# 以上
# 以小摶大
# 以示負責
# 以示善意
# 以利
# 以壯聲勢
# 以供
# 以便
# 以毒攻毒
# 以為
# 以致
# 以期
# 以期建立
# 以微笑對之
# 以誠相待
# 以遂己願
# 以達
# 以避免
# 以驚人
# 付託
# 付諸實施
# 付諸實現
# 付諸實踐
# 仔細
# 仔細看清
# 代言人
# 代表人物
# 代表作
# 代替
# 令人佩服
# 令人咋舌
# 令人振奮
# 令人高興
# 令人喜悅
# 令人愉快
# 令人景仰
# 令人欽佩
# 令人羡煞
# 令人鼓舞
# 令人滿意
# 令人滿意地
# 令人稱羨
# 令人興奮
# 令人難忘
# 令人歡迎
# 令人驚奇
# 令人矚目
# 令我悸動
# 仙丹
# 仙姿
# 充分
# 充分反映
# 充分支持
# 充分佐證
# 充分吸收
# 充分的理由
# 充分表現
# 充分表達
# 充分表徵
# 充分展現
# 充分尊重
# 充分掌握
# 充分發揮
# 充分溝通
# 充分準備
# 充分照顧
# 充分運用
# 充分證明
# 充分證據
# 充分顯示
# 充份
# 充份體現
# 充沛
# 充足
# 充足的證據
# 充當
# 充裕
# 充實
# 充滿
# 充滿希望
# 充滿信心
# 充滿信心地
# 充滿深情
# 充滿期待
# 充滿樂趣
# 充窩信
# 出人頭地
# 出任
# 出名
# 出色
# 出色表現
# 出奇的順
# 出奇熱絡
# 出面解決
# 出息
# 出神
# 出神入化
# 出馬
# 出動
# 出現
# 出現奇蹟
# 出掌
# 出運
# 出道
# 出線
# 出爐
# 凸顯
# 凸顯出
# 加入歐
# 加工
# 加分
# 加以完成
# 加以保護
# 加以討論
# 加以執行
# 加以採用
# 加以開發
# 加以實現
# 加以檢討
# 加快
# 加快研製
# 加快發展
# 加快開放
# 加快腳步
# 加怏
# 加油
# 加計
# 加倍
# 加倍努力
# 加倍增強
# 加冕
# 加強了
# 加強促進
# 加強宣導
# 加強訓練
# 加強推動
# 加強推廣
# 加強產業升級
# 加強提升
# 加強貿易
# 加速升級
# 加速交流
# 加速成長
# 加速完成
# 加速形成
# 加速展開
# 加速起飛
# 加速推展
# 加速推動
# 加速發展
# 加速進行
# 加發
# 加開
# 加溫
# 加裝
# 加緊
# 加緊把關
# 加緊做好
# 加緊腳步
# 加碼
# 加壓
# 加薪
# 功力十足
# 功成身退
# 功臣
# 功效
# 功德
# 功德無量
# 功德圓滿
# 功績
# 包容度高
# 包辦
# 北援
# 卡好
# 卡進
# 占有
# 占到
# 占取
# 占盡
# 占優勢
# 卯足全力
# 卯盡全力
# 去影響
# 可了解
# 可口
# 可予
# 可化解
# 可比
# 可以允許
# 可以化解
# 可以加入
# 可以如期開辦
# 可以成功
# 可以成為
# 可以有
# 可以考慮
# 可以改變
# 可以防止
# 可以享受
# 可以依據
# 可以使用
# 可以沾光
# 可以保留
# 可以恢復
# 可以持續
# 可以是
# 可以相信
# 可以容忍
# 可以高興
# 可以接受
# 可以發揮
# 可以順利
# 可以會
# 可以解決
# 可以預見
# 可以說
# 可以寫定
# 可以確定
# 可以緩解
# 可以談
# 可以幫助
# 可以應付
# 可以獲得
# 可以獲選
# 可以繼續
# 可以變化運用
# 可出爐
# 可用
# 可用於
# 可再增加
# 可如期
# 可考慮
# 可行
# 可行之道
# 可免
# 可利用
# 可完成
# 可扭轉頹勢
# 可見
# 可見一斑
# 可見是
# 可防止
# 可依靠
# 可使
# 可使用
# 可供
# 可協助
# 可取
# 可取得
# 可拉
# 可於
# 可知
# 可長可久
# 可信
# 可信任
# 可信賴
# 可信賴性
# 可促使
# 可為
# 可看
# 可效法
# 可真是
# 可能大增
# 可能加入
# 可能打開
# 可能用來
# 可能有利
# 可能很高
# 可能恢復
# 可能愈高
# 可能會促成
# 可追上
# 可得
# 可得到
# 可接受
# 可採
# 可採納
# 可望成功
# 可望成為
# 可望取代
# 可望放寬
# 可望拯救
# 可望重振
# 可望連莊
# 可望提升
# 可望順利展開
# 可望維持
# 可望增加
# 可理解
# 可規避
# 可透過
# 可喜
# 可尊敬
# 可循
# 可掌握
# 可期
# 可欽佩
# 可減輕
# 可貴
# 可貴情操
# 可媲美
# 可愛
# 可愛地
# 可敬
# 可敬重
# 可節省
# 可經營
# 可解決
# 可資運用
# 可達
# 可達到
# 可預見
# 可預期
# 可圖
# 可實行
# 可稱讚
# 可算
# 可維持
# 可認定
# 可說
# 可說是
# 可領到
# 可增加
# 可確保
# 可緩和
# 可誕生
# 可調度
# 可適用
# 可靠
# 可靠性
# 可靠程度
# 可據以
# 可獨得
# 可親
# 可謂為
# 可辨認
# 可選擇
# 可獲
# 可獲得
# 可避免
# 可證明
# 可證實
# 可繼續
# 可贏得
# 可攜帶
# 可讓
# 可觀
# 古典
# 古雅
# 召開
# 召集
# 召募
# 叮囑
# 另闢蹊徑
# 只有可能
# 只有可能是
# 只求
# 只是想
# 只要
# 只許
# 只循
# 只須
# 只想
# 只願
# 只願意
# 史上第一人
# 史上第一位
# 史上最大
# 史上最長
# 史上最高
# 史前未有
# 史無前例
# 叱吒
# 台柱
# 四分打點
# 外交利益
# 外交突破
# 外援
# 外輕鬆
# 失誤最少
# 孕育
# 巨人
# 巨大
# 巨大挑戰
# 巨步
# 巨型
# 巨星
# 巨變
# 巧合
# 巧妙
# 市場很大
# 平分
# 平分秋色
# 平心
# 平心靜氣
# 平平淡淡
# 平平靜靜
# 平白
# 平安
# 平安地
# 平抑
# 平和完成
# 平紀錄
# 平息疑問
# 平常心
# 平復
# 平等
# 平等互利
# 平等尊嚴
# 平等對待
# 平順
# 平整
# 平衡
# 平衡了
# 平衡發展
# 平靜
# 平靜下來
# 平穩
# 弘大
# 必有
# 必定
# 必定能
# 必定能夠
# 必要
# 必要性
# 必要措施
# 必能
# 必將
# 必得
# 必得演出
# 必勝
# 必然會
# 必然趨勢
# 必須及時
# 必須加入
# 必須加強
# 必須正視
# 必須有助於
# 必須完成
# 必須具備
# 必須注意
# 必須是
# 必須負擔
# 必須面對
# 必須面臨
# 必須能
# 必須接受
# 必須採取
# 必須透過
# 必須對信用的使用設限
# 必須確保
# 必須擴大
# 必會
# 必當
# 必經
# 必經階段
# 必需
# 必需存在
# 打主意
# 打出光芒
# 打出佳績
# 打出知名度
# 打包票
# 打拚
# 打破傳統
# 打動
# 打得好
# 打得更好
# 打得很好
# 打通
# 打造
# 打進
# 打開
# 打開知名度
# 打趣
# 打擊王
# 打贏
# 斥資
# 本色
# 本季最高
# 本著良心
# 本意
# 本標兼治
# 本應
# 未失
# 未失分
# 未打先轟動
# 未妨礙
# 未來趨勢
# 未受傷
# 未放棄
# 未牴觸
# 未被污染
# 未違
# 未違反
# 未演先轟動
# 未影響
# 未賣先紅
# 未篡改
# 未濫權
# 正大
# 正大光明
# 正代表著
# 正巧
# 正向
# 正合爐
# 正在規畫
# 正在進行
# 正好
# 正式
# 正式上路
# 正式批准
# 正式流通
# 正式要求
# 正式展開
# 正式送交
# 正式問世
# 正式啟用
# 正式啟動
# 正式揮別
# 正式登場
# 正式發行
# 正式結束
# 正式開市
# 正式開始
# 正式會晤
# 正式實施
# 正式敲定
# 正式誕生
# 正式簽署
# 正成立
# 正成形
# 正而意義
# 正直
# 正是
# 正是典型
# 正是時候
# 正派
# 正要
# 正面回應
# 正面地
# 正面的提升
# 正面的影響
# 正面肯定
# 正面效果
# 正面效益
# 正面效應
# 正面發展
# 正面評價
# 正面意義
# 正面影響
# 正面積極
# 正面幫助
# 正值
# 正常
# 正常人
# 正常化
# 正常行為
# 正常照顧
# 正統
# 正規
# 正朝著
# 正視
# 正準備
# 正當合理
# 正當性
# 正義
# 正義行為
# 正道
# 正確地
# 正確判斷
# 正確性
# 正確的決定了
# 正確無誤
# 正確點
# 母愛
# 民主
# 民主化
# 永久和平
# 永遠會記得
# 永遠關心
# 永續
# 永續利用
# 永續發展
# 永續經營
# 犯罪率
# 玄妙
# 玄奇
# 甘心
# 甘冒
# 甘美
# 甘甜
# 甘願
# 生力軍
# 生日快樂
# 生存能力
# 生存發展
# 生死與共
# 生育
# 生命力
# 生效
# 生氣勃勃
# 生氣勃勃地
# 生動
# 生情
# 生涯首勝
# 生涯高峰
# 生涯第一支
# 生涯最高
# 生產
# 生產力高
# 生產多
# 生意興隆
# 生還
# 用力刻劃
# 用心
# 用心良苦
# 用心規劃
# 用功
# 用來
# 由此可見
# 由衷
# 由衷支持
# 由衷的高興
# 由衷盼望
# 甲級
# 申辦
# 白金
# 白頭偕老
# 目光焦點
# 目睹
# 目標
# 矢志
# 矢言
# 石破天驚
# 示意
# 示範
# 立下宏願
# 立下榜樣
# 立功
# 立即回應
# 立即受惠
# 立即撤軍
# 立即趕工
# 立即檢查
# 立即歸返
# 立即顯現
# 立志
# 立足
# 立場一致
# 交心
# 交代清楚
# 交出
# 交往
# 交流
# 交流合作
# 交流熱絡
# 亦可
# 亦可以
# 亦在其中
# 亦步亦趨
# 亦是
# 亦是如此
# 亦為
# 亦應
# 伊甸園
# 休息
# 休戚與共
# 任命
# 仰望
# 仰慕
# 企及
# 企圖心強
# 光芒
# 光芒四射
# 光明
# 光明快樂
# 光明磊落
# 光采
# 光亮
# 光彩
# 光復
# 光滑
# 光榮
# 光輝
# 光澤
# 光環
# 先一步
# 先下一城
# 先下一盤
# 先予沿用
# 先行規劃
# 先決條件
# 先見之明
# 先制
# 先發制人
# 先進
# 先準備
# 先馳得點
# 先賢
# 先驅地位
# 全力
# 全力支持
# 全力以赴
# 全力把關
# 全力改善
# 全力拓展
# 全力拚戰
# 全力恢復
# 全力配合
# 全力參與
# 全力推動
# 全力演出
# 全力調查
# 全力整頓
# 全力積極
# 全才
# 全心全意
# 全心投入
# 全心貫注
# 全方位
# 全面
# 全面改善
# 全面流通
# 全面採取
# 全面清查
# 全面影響
# 全面整治
# 全面檢討
# 全神貫注
# 全能
# 全球共知
# 全球矚目
# 全透明
# 全部
# 全勝
# 全勝佳績
# 全然
# 全新
# 全盤修正
# 全靠
# 全靠自己
# 全壘打
# 全壘打王
# 全壘打製造機
# 全體動員
# 共同
# 共同主宰
# 共同主導
# 共同成為
# 共同利益
# 共同努力
# 共同步入
# 共同決定
# 共同角逐
# 共同防止
# 共同享受
# 共同承擔
# 共同的結論
# 共同信守
# 共同保持
# 共同促進
# 共同宣布
# 共同宣言
# 共同流通
# 共同討論
# 共同參加
# 共同參與
# 共同採用
# 共同票選
# 共同組成
# 共同發布
# 共同發展
# 共同訴求
# 共同愛護
# 共同解決
# 共同領先
# 共同慶祝
# 共同戰略
# 共同擬定
# 共同聲明
# 共同願望
# 共存
# 共存繁榮
# 共事
# 共享
# 共信共守
# 共通點
# 共創
# 共創未來
# 共鳴
# 共擔
# 共獲
# 共舉
# 共襄盛舉
# 共識
# 共轟出
# 共體時艱
# 再下一城
# 再生能源
# 再立新功
# 再安排
# 再收取
# 再行
# 再見全壘打
# 再見安打
# 再見逆轉安打
# 再度
# 再度拉開
# 再度挑起
# 再度展現
# 再度獲得
# 再度獲獎
# 再度獲選
# 再展威風
# 再起
# 再接再厲
# 再添
# 再添一筆
# 再現光明
# 再現虎威
# 再造
# 再創
# 再創紀錄
# 再創高峰
# 再創新高
# 再創新猷
# 再發虎威
# 再進步
# 再圓
# 再獲殊榮
# 再贏
# 再顯威風
# 列入
# 列為
# 列強環伺
# 列舉
# 匡正
# 印証
# 印象深刻
# 危機意識
# 吉利
# 吉星高照
# 吉祥
# 同一陣
# 同一陣線
# 同一陣營
# 同一國
# 同台揮桿
# 同舟共濟
# 同步
# 同步通過
# 同步發行
# 同步實施
# 同步適用
# 同享榮耀
# 同奏凱歌
# 同胞好友
# 同時
# 同時參加
# 同時產生
# 同時開列
# 同時達到
# 同尉
# 同情心
# 同組較勁
# 同組競技
# 同場競技
# 同等重要
# 同意
# 同意合作
# 同意承認
# 同意接受
# 同意給予
# 同意鼓勵
# 同感
# 同盟
# 同蒙其利
# 同樣重要
# 同樣堅強
# 同聲歡迎
# 各各樣
# 各式各樣
# 各取所需
# 向上調整
# 向心力
# 向來
# 向前
# 向前行
# 向前推進
# 向前跨
# 向善
# 名列前茅
# 名列第一
# 名作
# 名利雙收
# 名流
# 名流雲集
# 名留青史
# 名副其實
# 名將
# 名媛
# 名號
# 名滿天下
# 名聲
# 合力
# 合乎情理
# 合乎衛生
# 合乎邏輯
# 合作
# 合作互補
# 合作協議
# 合作追求
# 合作統一
# 合宜
# 合法
# 合法化
# 合法申報
# 合法技術
# 合法性
# 合法產生
# 合法程序
# 合格
# 合情理
# 合理
# 合理分配
# 合理化
# 合理性
# 合理劃分
# 合理價位
# 合意
# 合群
# 合演
# 合算
# 合適
# 合適地
# 合諧
# 合辦
# 合縱連橫
# 合邏輯
# 吃定
# 吃苦
# 吃苦耐勞
# 后望
# 因禍得福
# 因應
# 因應之道
# 因應改善
# 回升
# 回心轉意
# 回到
# 回昇
# 回春
# 回流
# 回首
# 回神
# 回報
# 回復
# 回敬
# 回補
# 回憶
# 回歸
# 回穩
# 回饋
# 回顧
# 地位
# 地基
# 在一起
# 在乎
# 在所不惜
# 在所難免
# 在家一條龍
# 在贊成方面
# 多一點
# 多才多藝
# 多元
# 多元地理環境
# 多出
# 多出一倍
# 多出許多
# 多加油
# 多加強
# 多半
# 多半會
# 多生產
# 多幸褔
# 多所協助
# 多於
# 多采多姿
# 多姿多釆
# 多為
# 多得很
# 多得是
# 多添
# 多產
# 多智
# 多極化
# 多達
# 多福
# 多樣化
# 多樣性
# 多趣
# 多贏
# 妄圖
# 好一點
# 好天氣
# 好太多
# 好心
# 好心情
# 好手
# 好方法
# 好日子
# 好吃
# 好多了
# 好好地
# 好好消化
# 好好做好
# 好好規劃
# 好年
# 好米
# 好似
# 好事者
# 好幸運
# 好玩
# 好的表現
# 好的開始是成功的一半
# 好的戲
# 好客
# 好很多
# 好看
# 好家在
# 好時機
# 好消息
# 好神
# 好追根究底
# 好彩頭
# 好球
# 好報
# 好景
# 好評
# 好開心
# 好意
# 好意地
# 好感
# 好想
# 好極
# 好極了
# 好解決
# 好運
# 好運接著來
# 好過
# 好像
# 好實力
# 好認
# 好學
# 好機會
# 好辦法
# 好選手
# 好懂
# 好戲
# 好轉
# 好聽
# 如日中天
# 如火如荼
# 如出一轍
# 如同
# 如約
# 如能
# 如期
# 如期召開
# 如期完成
# 如期推出
# 如期進行
# 如期開辦
# 如畫
# 如意算盤
# 如預期
# 如願
# 如願上演
# 如釋重負
# 如釋重擔
# 存在
# 存有
# 存活
# 存洧功率
# 存著
# 存證
# 守住
# 守法
# 守信
# 守得雲開
# 守護
# 安了心
# 安心
# 安可
# 安打
# 安全又新
# 安全利益
# 安全改進
# 安全防禦
# 安全突破
# 安全產品
# 安全感
# 安全網
# 安好
# 安安靜靜
# 安安穩穩
# 安身
# 安身立命
# 安和
# 安和樂利
# 安命
# 安定
# 安定和平
# 安定援助
# 安於
# 安度
# 安泰
# 安康
# 安祥
# 安然
# 安逸
# 安閒
# 安置
# 安詳
# 安寧
# 安睡
# 安樂
# 安適
# 安靜
# 安穩
# 尖兵
# 尖端
# 屹立
# 年度MVP
# 年度最佳
# 年度最佳球員
# 年紀輕輕
# 年輕
# 年輕化
# 年輕好手
# 年輕有成
# 年輕貌美
# 忙於
# 忙著
# 成了
# 成千上萬
# 成功
# 成功地
# 成功利用
# 成功典範
# 成功封王
# 成功率
# 成功掌握
# 成功發展
# 成功落幕
# 成功解決
# 成功演出
# 成功締造
# 成功舉行
# 成本更低廉
# 成立在即
# 成交
# 成形
# 成果豐碩
# 成長甚為快速
# 成長茁壯
# 成長趨勢
# 成為
# 成為大勢所趨
# 成為熱門
# 成氣候
# 成真
# 成就不凡
# 成就出
# 成就感
# 成熟
# 成熟智慧
# 成熟穩重
# 成績
# 成績最好
# 成績斐然
# 扣人心弦
# 扣人心懸
# 收入
# 收入最高
# 收下
# 收到了效果
# 收受
# 收效
# 收益
# 收集
# 收過
# 收藏
# 收穫
# 早日解決
# 早日過關
# 早日實現
# 早速
# 旨在
# 有一致性
# 有一套
# 有人力
# 有力
# 有才氣
# 有才能
# 有才智
# 有才幹
# 有才幹的人
# 有不少
# 有分寸
# 有反應
# 有天資
# 有天賦
# 有心得
# 有主權
# 有以致之
# 有充分時間
# 有功
# 有功績
# 有可為
# 有必要
# 有本錢
# 有正面作用
# 有正面意義
# 有用
# 有用籌碼
# 有目共睹
# 有光澤
# 有先見之明
# 有共識
# 有同情心
# 有同感
# 有名
# 有好處
# 有如神助
# 有成果
# 有此機會
# 有自信
# 有何不可
# 有判斷力
# 有利
# 有利支撐
# 有利於
# 有利弭平
# 有利益
# 有利條件
# 有利潤
# 有助
# 有助改善
# 有助和平
# 有助於
# 有助恢復
# 有助益
# 有助益的東西
# 有助紓解
# 有吸引力
# 有含義
# 有希望
# 有志
# 有志一同
# 有志成為
# 有把握
# 有把握地
# 有改善
# 有更多
# 有決心
# 有足夠
# 有些道理
# 有些關係
# 有使命感
# 有兩下子
# 有其
# 有其必要
# 有其意義
# 有所了解
# 有所助益
# 有所改善
# 有所改變
# 有所貢獻
# 有所期待
# 有所進展
# 有所遵循
# 有所幫助
# 有所變動
# 有所讓步
# 有知覺
# 有表現
# 有信心
# 有保障
# 有前途
# 有勁
# 有厚利可圖
# 有品格
# 有威嚴
# 有建設性
# 有待
# 有待澄清
# 有待調查
# 有思想
# 有思想性
# 有指望
# 有相似之處
# 有看頭
# 有突破
# 有耐性
# 有計畫
# 有重大興趣
# 有面子
# 有效
# 有效平順
# 有效因應
# 有效利用
# 有效防禦
# 有效使用
# 有效協助
# 有效性
# 有效的利用
# 有效強化
# 有效率
# 有效票
# 有效發揮
# 有效遏止
# 有效實施
# 有根據
# 有氣質
# 有特色
# 有益
# 有益於健康
# 有益健康
# 有秩序
# 有能力
# 有財產
# 有貢獻
# 有高度興趣
# 有情有義
# 有掖義
# 有教育意義
# 有望
# 有望成為
# 有條件
# 有條理
# 有理
# 有理由相信
# 有眼光
# 有眼福
# 有規矩
# 有規範
# 有責任
# 有責任心
# 有備而來
# 有創造力
# 有創意
# 有掌聲
# 有智慧
# 有朝一日
# 有結果
# 有著
# 有貴族氣派
# 有進取精神
# 有雅量
# 有韌性
# 有勢力
# 有幹勁
# 有意支持
# 有意於
# 有意接下
# 有意透過
# 有意提升
# 有意義
# 有意跟進
# 有意願
# 有感而發
# 有感覺
# 有愛心
# 有愛國心
# 有新意
# 有極大助益
# 有節制
# 有經驗
# 有義務
# 有話直說
# 有跡可循
# 有道理
# 有道德
# 有實力
# 有精神
# 有說有笑
# 有說服力
# 有遠見
# 有需要
# 有價值
# 有價值的人
# 有彈性
# 有彈性的調適
# 有樣學樣
# 有模有樣
# 有樂趣
# 有熱情
# 有確實根據
# 有趣
# 有餘
# 有魅力
# 有擔當
# 有機會
# 有機會取代
# 有興趣
# 有賴於
# 有辦法
# 有錢
# 有頭腦
# 有償債能力
# 有幫手
# 有幫助
# 有幫助的人
# 有膽量
# 有點類似
# 有禮
# 有禮貌
# 有禮貌的行為
# 有竅門
# 有關
# 有關重大
# 有魔力
# 有權
# 有權力
# 有權利
# 有權益
# 有權能
# 有權採取
# 有鑑於
# 有鑑於此
# 有顯著幫助
# 此勝
# 死灰復燃
# 江山
# 江山代有才人出
# 百分之百
# 百分之百支持
# 百分滿點
# 百家爭鳴
# 百戰沙場
# 老成
# 老而彌堅
# 老想著
# 老實
# 老辣
# 老遠趕來
# 考察
# 考慮跟進
# 而在
# 而是
# 而會
# 肉質更佳
# 自力救濟
# 自主
# 自主性
# 自主意志
# 自主解決
# 自主選擇
# 自幼景仰
# 自由
# 自由化
# 自由化、彈性化
# 自由地
# 自由自在
# 自由行動
# 自由流通
# 自由發揮
# 自由選擇
# 自白
# 自立
# 自立自強
# 自在
# 自如
# 自成頂級
# 自行實驗
# 自行選擇
# 自行擬定
# 自助
# 自告奮勇
# 自我防衛
# 自我解嘲
# 自我選擇
# 自制
# 自承
# 自治
# 自治研習
# 自治規定
# 自治監督
# 自知之明
# 自信
# 自信心高潮
# 自信地
# 自信滿滿
# 自保
# 自勉
# 自動
# 自得
# 自得其樂
# 自得於
# 自救
# 自理管轄
# 自許
# 自尊
# 自期
# 自然
# 自然可期
# 自然會
# 自然應是
# 自傲
# 自愛
# 自詡成功
# 自豪
# 自衛
# 自願提供
# 自願擔任
# 至上
# 至孝
# 至表歡迎
# 至為明顯
# 至盼
# 至美
# 至高
# 至高榮耀
# 至深至遠
# 至善
# 至樂
# 至關重大
# 至關重要
# 色彩繽紛
# 血濃於水
# 行有餘力
# 行使
# 行家
# 行動
# 行強
# 行得端坐得正
# 行善
# 衣履光鮮
# 串連
# 位居領先
# 位居關鍵
# 何不可
# 估算
# 佐證
# 伺機而動
# 伸出
# 伸出手救援
# 伸出援手
# 伸虎爪
# 伸展
# 伸張
# 伸援
# 佔了
# 佔上風
# 佔到優勢
# 似天使
# 似乎
# 似乎有理
# 似乎表示
# 似曾相識
# 但仍應有
# 作出不少貢獻
# 作出決定
# 作出賠償
# 作出選擇
# 作好
# 作成
# 作定奪
# 作後盾
# 作為
# 作為獎品
# 作美
# 作準備
# 作證
# 你儂我儂
# 低廉
# 伶俐
# 佈下
# 兌現
# 克服經濟困難
# 克服難關
# 免於受苦
# 免遭
# 冷戰結束
# 冷靜地
# 冷靜決定
# 別致
# 別無二致
# 別緻
# 判處
# 判斷力
# 判讀
# 利大於弊
# 利多
# 利多於弊
# 利於
# 利益均霑
# 利基
# 利基市場
# 利得
# 利潤
# 利器
# 助人
# 助手
# 助於
# 助長了
# 助威
# 助益
# 助陣
# 助隊
# 助勢
# 助選
# 努力
# 努力不懈
# 努力完成
# 努力爭取
# 努力研究
# 努力尋求
# 努力解決
# 努力緩和
# 努力謀求
# 即日
# 即日起
# 即可
# 即可參加
# 即可獲贈
# 即有
# 即為
# 即將
# 即將成立
# 即將成為
# 即將完成
# 即將來臨
# 即將到來
# 即將啟動
# 即將進行
# 即將開打
# 吞得下去
# 呈現
# 呈報
# 君子之爭
# 告
# 告一段落
# 告捷
# 告訴
# 告贏
# 吻合
# 吸引人
# 吸引人的事物
# 吸引力
# 吸走
# 吸納
# 含笑
# 含情脈脈
# 含蓄
# 均勻
# 均可
# 均有
# 均表示
# 均能享受
# 均採用
# 均等
# 均勢
# 均認為
# 均需參加
# 均衡
# 均衡發展
# 均霑
# 均應
# 坐收
# 坐鎮
# 坐穩
# 坐穩首位
# 壯大
# 壯聲勢
# 壯舉
# 壯闊
# 壯麗
# 壯麗雄偉
# 壯觀
# 妙不可言
# 妙計
# 妙極
# 妊
# 妥協
# 妥善
# 妥善因應
# 妥善安排
# 妥善完成
# 妥善執行
# 妥善處理
# 妥善規畫
# 妥善規劃
# 妥當
# 妥適
# 妥擬
# 孝行
# 孝弟
# 孝順
# 孝敬
# 完全化解
# 完全反映
# 完全比照
# 完全依法
# 完全取代
# 完全和平
# 完全致力
# 完全展現
# 完全採納
# 完全符合
# 完全滿意
# 完全整合
# 完好
# 完成
# 完成了
# 完成修正
# 完投
# 完投勝
# 完封
# 完封勝
# 完美
# 完美的結合
# 完美無缺
# 完美結合
# 完美演出
# 完備
# 完善
# 完滿
# 完整規畫
# 宏大
# 宏偉
# 宏規
# 宏觀
# 宏觀願景
# 局面底定
# 希望
# 希望大增
# 希望中央一定要信守承諾
# 希望協助
# 希望爭取
# 希望能
# 希望維持
# 希望說服
# 希冀
# 庇佑
# 形同
# 形同一體
# 形成共識
# 形成這個共識
# 形影不離
# 形影不離的朋友
# 彷彿
# 志哀
# 志得意滿
# 志願
# 忍不住
# 忍耐力
# 快了許多
# 快刀斬亂麻
# 快上
# 快快活活
# 快快樂樂
# 快步追上
# 快馬加鞭
# 快速
# 快速合作
# 快速成長
# 快速改善
# 快速起飛
# 快速統一
# 快速進行
# 快速進展
# 快速解決
# 快速擴張
# 快意
# 快感
# 快樂
# 快樂主義
# 快樂主義者
# 快樂地
# 快樂論
# 戒除
# 戒慎
# 戒護
# 我的職責
# 技巧
# 技術上可行
# 技術純熟
# 技驚四座
# 技驚全場
# 扶正
# 扶助
# 扶植
# 扶搖直上
# 扭轉劣勢
# 扭轉乾坤
# 扭轉情勢
# 扭轉頹勢
# 把火撲滅
# 把握
# 把握良機
# 把握時機
# 把握機會
# 把穩
# 找出
# 找出來
# 找回公義
# 找回球感
# 找到
# 找到樂趣
# 批准
# 批核
# 扳平
# 扳回
# 扳回一城
# 扳回頹勢
# 扳成
# 抒情
# 抒發
# 抒解
# 抒懷
# 折服
# 扮演
# 投入
# 投身
# 投其所好
# 投注
# 投注極大努力
# 投桃報李
# 投誠
# 投資
# 投資增加
# 投滿
# 投懷送抱
# 抓住機會
# 改良
# 改良式
# 改革成功
# 改革開放
# 改善了
# 改善援助
# 改善體質
# 改過自新
# 改寫
# 改頭換面
# 改變
# 改變了
# 攻上
# 攻占
# 攻佔榜首
# 攻進
# 攻勢猛烈
# 攻讀
# 攸關
# 更了解
# 更上一層樓
# 更上層樓
# 更久
# 更大
# 更方便
# 更加充分
# 更加成熟
# 更加努力
# 更加吸引
# 更加活絡
# 更加重視
# 更加高漲
# 更加敏感
# 更加熱絡
# 更加穩定
# 更可
# 更可取
# 更可藉
# 更可觀
# 更外向
# 更民主
# 更合理
# 更多
# 更多好手
# 更多倍
# 更多商機
# 更好
# 更好一點
# 更好看
# 更成熟
# 更有
# 更有力
# 更有可能
# 更有必要
# 更有利
# 更有吸引力
# 更有信心
# 更有效
# 更有效率
# 更有商機
# 更有理由
# 更有說服力
# 更有彈性
# 更有機會
# 更有療效
# 更低成本
# 更低廉
# 更吸引力
# 更快
# 更快籌措
# 更迅速
# 更佳
# 更具
# 更具有效率
# 更具效率
# 更具國際觀
# 更具彈性
# 更受矚目
# 更和平
# 更旺
# 更是
# 更是如此
# 更是特別
# 更為光明
# 更為有利
# 更為直接
# 更為重要
# 更為強大
# 更為增強
# 更為廣泛
# 更為濃厚
# 更為激烈
# 更為簡便
# 更為簡單
# 更看重
# 更美
# 更要
# 更重要
# 更容易
# 更容易選擇
# 更留意
# 更能
# 更高
# 更高水準
# 更高招
# 更高層級
# 更務實
# 更堅強
# 更堅實
# 更密切
# 更強
# 更強盛
# 更接近
# 更清楚
# 更深一層
# 更喜歡
# 更富彈性
# 更棒
# 更貴
# 更進一步
# 更傲人
# 更感謝
# 更想
# 更愛
# 更準
# 更像
# 更實
# 更精進
# 更緊密
# 更需
# 更增加
# 更廣大
# 更廣泛
# 更廣泛與深入
# 更適當
# 更激烈
# 更積極
# 更積極地
# 更應
# 更應該
# 更懂得
# 更瞭解
# 更趨一致性
# 更趨穩定
# 更趨嚴格
# 更擴大
# 更穩定
# 更難得
# 更嚴謹
# 更耀眼
# 更顯篤定
# 更靈活
# 步入
# 步入軌道
# 步伐一致
# 步步為營
# 步調一致
# 每戰必勝
# 求生
# 求同存異
# 求好
# 求好心切
# 求取
# 求取進步
# 求能
# 求得
# 求勝
# 求勝意志
# 求援
# 求新
# 求歡
# 沈著
# 沈著應變
# 沈醉
# 沈穩
# 沈穩內斂
# 決定向
# 決定性
# 決策
# 決意
# 決論
# 決戰
# 決斷
# 決斷力
# 決議
# 決議成立
# 沖勁
# 沒人懷疑
# 沒有兩樣
# 沒有放棄
# 沒有問題
# 沒有異議
# 沒有錯
# 沒問題
# 沒閒著
# 沒錯
# 沃野
# 汲汲於
# 汲取教訓
# 牢固
# 牢靠
# 狂勝
# 狂喜
# 狂愛
# 狂熱加油
# 狂熱讚揚
# 狂歡
# 男子漢
# 究竟
# 肝膽相照
# 良心
# 良方
# 良多
# 良好
# 良好合作
# 良好形象
# 良好訓練
# 良好教育
# 良好開端
# 良好機會
# 良好關係
# 良性
# 良性互動
# 良性發展
# 良性溝通
# 良性競爭
# 良將
# 良策
# 良善
# 良質米
# 良機
# 見仁見智
# 見真章
# 見獵心喜
# 見證
# 角逐
# 言之鑿鑿
# 言出必行
# 言而有信
# 言笑晏晏
# 言歸於好
# 谷底回升
# 走入
# 走上正途
# 走出
# 走出低潮
# 走出谷底
# 走出陰影
# 走向
# 走向和平
# 走向和解
# 走向國際化
# 走向統一
# 走回競爭
# 走好運
# 走強
# 走進
# 走勢強勁
# 足以
# 足以傲人
# 足以影響
# 足以應付
# 足以顯示
# 足可
# 足見
# 足足擁有
# 足夠
# 足夠的信心
# 足備
# 足智多謀
# 足與
# 足與美國匹敵
# 身手
# 身為
# 身負重責
# 身強體壯
# 身價大漲
# 辛勤耕耘
# 迅速
# 迅速地
# 迅速處置
# 迅速補抓
# 那麼大
# 里程碑
# 防水
# 防火障
# 防線
# 防護罩
# 並不對峙
# 並列第一
# 並列領先
# 並列雙雄
# 並沒有錯
# 並居
# 並肩
# 並肩作戰
# 並肩殺進
# 並肩競技
# 並要
# 並無不妥
# 並無不便
# 並無差異
# 並無異常
# 並進
# 並駕齊驅
# 並應
# 並顧
# 並驅
# 事在人為
# 事成
# 事跡
# 事實
# 事實上
# 事實證明
# 享用
# 享有
# 享受
# 享受到
# 享譽
# 依法
# 依法行事
# 依恃
# 依約履行
# 依理
# 依現狀
# 依規定
# 依循
# 依然
# 依然有效
# 依然是
# 依然犀利
# 依照
# 依據
# 依歸
# 依舊
# 依舊是
# 依舊犀利
# 佳作
# 佳音
# 佳評如潮
# 佳話
# 佳境
# 佳績
# 使人信服
# 使人首肯
# 使人敬畏
# 使之生效
# 使出
# 使平坦
# 使平靜
# 使平靜下來
# 使用
# 使用方便
# 使安靜
# 使免除
# 使命
# 使固定
# 使相等
# 使涼快
# 使陶醉
# 使喚
# 使精細
# 使緩和
# 使醉心
# 供娛樂用
# 供援
# 供應
# 例行公事
# 來日方長
# 來的高
# 來得殷切
# 來得高
# 來勢洶洶
# 侃侃而談
# 併列
# 併行
# 併購整合
# 佩服
# 兩分打點
# 兩分打點安打
# 兩分全壘打
# 兩全
# 兩倍多
# 兩黨的共識
# 具水準
# 具成效
# 具有
# 具有生殖力
# 具吸引力
# 具足
# 具体
# 具信心
# 具建設性
# 具指標意義
# 具挑戰性
# 具彈性
# 具影響力
# 具競爭力
# 具體化
# 具體回應
# 具體地說
# 具體行動
# 具體改革
# 具體協議
# 具體跡
# 具體跡象
# 其來有自
# 其實
# 典雅
# 典範
# 刻意凸顯
# 刷新
# 刷新紀錄
# 刺激成長
# 到處都是
# 到處搜尋
# 到訪
# 到場致祭
# 到期
# 到達
# 到達高峰
# 刮目相看
# 制止危機
# 制定
# 制定完善
# 制度化
# 制訂
# 協力
# 協同
# 協作
# 協助
# 協助促進
# 協助善後
# 協助維護
# 協助應付
# 協防
# 協定
# 協商同意
# 協商而成
# 協商通過
# 協商解決
# 協商議決
# 協尋
# 協調、尊重
# 協議生效
# 協議訂出
# 協議書
# 卓有成效
# 卓著
# 卓越
# 卓越貢獻
# 取代
# 取向
# 取利
# 取決
# 取到
# 取信
# 取信於
# 取悅
# 取消或放寬
# 取得了
# 取得交集
# 取得全勝佳績
# 取得共識
# 取得協調
# 取得協議
# 取得勝利
# 取得超前
# 取得進展
# 取得領先
# 取道
# 取樂
# 受人矚目
# 受大眾歡迎
# 受用
# 受利
# 受到注意
# 受到重視
# 受到鼓舞
# 受到激勵
# 受命
# 受注目
# 受信任
# 受重視
# 受益
# 受益良多
# 受益匪淺
# 受理
# 受惠
# 受惠於
# 受惠最多
# 受鼓舞
# 受邀
# 受鍾愛
# 受寵
# 受歡迎
# 受矚目
# 呵呵
# 呼之欲出
# 呼叫
# 呼朋引伴
# 呼風喚雨
# 呼應
# 呼應唱和
# 呼聲最高
# 呼籲
# 和平
# 和平用途
# 和平共存
# 和平共處
# 和平往來
# 和平統一
# 和平進程
# 和平愛好者
# 和平解決
# 和平穩定
# 和平關係
# 和好
# 和事佬
# 和氣
# 和善氣氛
# 和睦
# 和樂
# 和緩
# 和談
# 和諧
# 和藹
# 和藹可親
# 周到
# 周密
# 周詳
# 命中
# 命令調整
# 固守
# 固若金湯
# 固然
# 固然很好
# 固然應該
# 坦白
# 坦言
# 坦直
# 坦率
# 坦途
# 坦然
# 坦誠
# 坦誠地
# 坦誠面對
# 奉命
# 奉送
# 奉獻
# 奇妙
# 奇佳
# 奇異
# 奇準
# 奇葩
# 奇跡
# 奇蹟
# 奔走
# 奔走聲援
# 奔相走告
# 委派
# 委婉
# 委請
# 委辦
# 始可
# 始得
# 始終一貫
# 始終不變
# 定下
# 定出
# 定為
# 定案
# 定能統一
# 定會
# 定論
# 定讞
# 宜人
# 宜由
# 宜早日因應
# 宜考慮
# 宜採
# 宜避免
# 尚方寶劍
# 尚好
# 尚有
# 尚有可觀
# 尚能
# 尚須
# 尚屬
# 居上風
# 居中協調
# 居功
# 居功厥偉
# 居多
# 居冠
# 居首
# 居首位
# 居高不下
# 幸好
# 幸運
# 幸運地
# 幸福
# 幸福美滿
# 幸靠
# 幸虧
# 延年益壽
# 延伸
# 延續
# 延攬
# 往上
# 往上攀升
# 往上飆
# 往日榮光
# 往前
# 往前發展
# 征服四海
# 忠心
# 忠厚
# 忠貞
# 忠恕
# 忠耿
# 忠愛
# 忠誠
# 忠誠和賣命
# 忠誠的行為
# 忠實
# 忠實表達
# 忠黨愛國
# 怏得多
# 怏速
# 怏速展開
# 性能也大幅提升
# 性能為佳
# 性能優越
# 性感
# 所向披靡
# 所向無敵
# 所言屬實
# 所幸
# 所知
# 所致
# 所能
# 所得
# 所需
# 所樂於看到
# 所遭
# 所獲
# 承接
# 承諾
# 承辦
# 承歡
# 承襲
# 承讓
# 拉一把
# 拉力
# 拉大
# 拉他們一把
# 拉抬
# 拉開
# 拉攏
# 招手
# 招待
# 招待周到
# 招降
# 招牌微笑
# 招認
# 招攬
# 拓建
# 拓展
# 拓展版圖
# 拓銷
# 拔足緊跟
# 拔得頭籌
# 拔擢
# 拍手歡呼
# 拍板決定
# 拍板定出
# 拍板定案
# 拍板敲定
# 抵達
# 拚一下
# 拚到
# 拚命
# 拚命苦練
# 拚得過
# 拚戰
# 拚戰激烈
# 抱回
# 抱有
# 抱走冠軍
# 抱持
# 抱持樂觀
# 抬頭
# 放下武器
# 放大美化
# 放心
# 放手
# 放手一搏
# 放手去做
# 放手推行
# 放軟
# 放置
# 放輕鬆
# 放膽
# 斧鑿突圍
# 於法有據
# 旺季
# 旺健
# 旺盛
# 易如反掌
# 易成為
# 易於
# 易於理解
# 易得
# 易控制
# 易理解
# 易造成
# 易管理
# 易與
# 易辦
# 易懂
# 易讀
# 昌盛
# 昂首闊步
# 昂揚
# 明了
# 明日之星
# 明白
# 明示
# 明告
# 明志
# 明定
# 明亮
# 明亮照耀
# 明星球員
# 明訂
# 明朗
# 明朗化
# 明理
# 明晰
# 明智
# 明智之舉
# 明智決定
# 明智的行為
# 明確
# 明確保障
# 明確指出
# 明確規定
# 明辨
# 明瞭
# 明顯
# 明顯成長
# 明顯改善
# 明顯提升
# 明顯發現
# 明顯進展
# 明顯增加
# 明顯轉強
# 昇級
# 昇遷
# 服氣
# 服務佳
# 服務誠意
# 服從
# 東山再起
# 果決
# 果真如此
# 果敢
# 果然
# 果斷
# 果斷力
# 枇核
# 林清江
# 杼困
# 欣欣
# 欣欣向榮
# 欣喜
# 欣喜若狂
# 欣然
# 欣然同意
# 欣然地
# 欣慰
# 欣賞
# 武力優勢
# 注入
# 注入砍
# 注入動力
# 注目
# 注定
# 注重
# 注重實際
# 注意
# 沾光
# 波動
# 法定
# 法律
# 法寶
# 油然而生
# 治本
# 治好
# 治病
# 泯恩仇
# 炒高
# 炒得正熱
# 炒得很熱
# 炒熱
# 爭光
# 爭回
# 爭取儘速
# 爭取雙贏
# 爭長短
# 爭冠
# 爭相湧進
# 爭看
# 爭氣
# 爭逐
# 爭勝
# 爭進
# 爭雄
# 爭睹
# 爭鋒
# 爭辦
# 爭霸
# 物美價廉
# 物廉價美
# 狀況良好
# 狀況很好
# 狀況最好
# 玩樂
# 的確
# 的確地
# 的確有
# 的確有權
# 的確是
# 直言
# 直言不諱
# 直到
# 直奔
# 直指
# 直接
# 直接助益
# 直接指名
# 直接參與
# 直接接管
# 直率
# 直誇
# 直截了當
# 直線上升
# 直衝
# 知之甚詳
# 知名
# 知足
# 知性
# 知恥
# 知恩
# 知會
# 知罪
# 知曉了
# 知覺
# 秉承
# 秉持
# 空中主力
# 空前
# 空前成就
# 空前紀錄
# 空前偉大
# 空前盛大
# 糾正
# 肥沃
# 肯切
# 肯定
# 肯定詞
# 肯定維持
# 肯定語
# 肯順從
# 芳名
# 芳香
# 花容
# 芬芳
# 虎虎生風
# 虎姿流露
# 虎威蓋世
# 虎威懾人
# 虎視眈眈
# 虎嘯低吼
# 初步
# 初步同意
# 初步勘查
# 初步認為
# 初步確定
# 初定
# 表示
# 表示支持
# 表示肯定
# 表示尊重
# 表示謝意
# 表示贊成
# 表示關切
# 表示歡迎
# 表示讚許
# 表決通過
# 表明
# 表現
# 表現不錯
# 表現出色
# 表現突出
# 表現神勇
# 表現得更好
# 表現最好
# 表現最佳
# 表現越好
# 表現精采
# 表現優異
# 表現穩定
# 表現穩健
# 表揚
# 表達決心
# 表達善意
# 表達歉意
# 表達歡迎
# 表彰
# 表態支持
# 表謝意
# 迎刃而解
# 迎向
# 迎接
# 迎賓
# 迎戰
# 迎頭趕上
# 返老還童
# 近乎完美
# 近在眼前
# 近況大勇
# 近況奇佳
# 近況很好
# 近況頗佳
# 金手套
# 金玉
# 金剛
# 金援
# 金牌得主
# 金融中心
# 長久獨大
# 長打威力
# 長足
# 長命
# 長命百歲
# 長治久安
# 長相廝守
# 長紅
# 長處
# 長袖善舞
# 長期
# 長期同盟
# 長期安定
# 長期看好
# 長期展望
# 長期追求
# 長進
# 長遠利益
# 門當戶對
# 雨過天青
# 青出於藍勝於藍
# 青春活力
# 青睞
# 非凡
# 非比尋常
# 非他莫屬
# 非自責失分
# 非虎莫屬
# 非常
# 非常大方
# 非常合適
# 非常好
# 非常有用
# 非常希望
# 非常明確
# 非常明顯
# 非常重要
# 非常重視
# 非常特別
# 非常高
# 非常高興
# 非常接近
# 非常甜蜜
# 非常進步
# 非常順利
# 非常感謝
# 非常詳細
# 非常誠懇
# 非常榮幸
# 非常需要
# 非常興奮
# 非常簡單
# 非常關心
# 非常驕傲
# 佼佼者
# 矻矻
# 亟力
# 亟力開拓
# 亟宜
# 亟待
# 亟待釐清
# 亟思
# 亟欲
# 亟須
# 亟需
# 亭亭
# 亮相機會
# 亮麗
# 信心
# 信心十足
# 信心大增
# 信心喊話
# 信心極強
# 信心滿滿
# 信以為真
# 信任
# 信守承諾
# 信最
# 信實
# 信誓旦旦
# 信賴
# 信賴性
# 信賴感
# 信譽
# 便可解決
# 便利
# 便利性
# 俠義
# 保安
# 保有自尊
# 保住
# 保佑
# 保持
# 保持低調
# 保持很好
# 保持連絡
# 保持領先
# 保送
# 保密
# 保得
# 保障支持
# 保障福利
# 保衛
# 保證
# 保證好
# 保證增加
# 保證遵循
# 保釋
# 促升
# 促加速
# 促成
# 促成統一
# 促其
# 促其取得
# 促建
# 促統
# 促進
# 促進和解
# 促進統一
# 促請
# 促銷
# 俘獲
# 俊氣
# 冒出
# 冒出頭來
# 冒險前進
# 冠軍
# 冠軍中的冠軍
# 冠軍丰采
# 冠軍在握
# 冠蓋雲集
# 削足適履
# 前住
# 前來
# 前往
# 前所未有
# 前所未見
# 前途
# 前景
# 前景可期
# 前景看好
# 前鋒
# 前瞻
# 前瞻、創新
# 前瞻性
# 前瞻部署
# 剋期
# 則須
# 勇於
# 勇於面對
# 勇氣
# 勇氣可嘉
# 勇猛
# 勇敢
# 勇敢地
# 勇敢的行為
# 勇敢的事跡
# 勇敢傑出
# 勇奪
# 勇毅
# 勇闖
# 勉勵
# 勃興
# 勁道
# 勁道很強
# 勁敵
# 勁爆
# 南征北討
# 厚植
# 厚愛
# 厚道
# 厚實
# 厚德
# 厚禮
# 咬牙撐住
# 咬得緊
# 咬緊牙根
# 咸信
# 咸料
# 咸認
# 品行
# 品行端正
# 品味
# 品性端正
# 品質高
# 哈哈
# 咧開了笑臉
# 城鄉公平
# 契機
# 奏效
# 奏捷
# 威信
# 威風
# 威脅也小
# 威脅降低
# 威猛
# 威勢
# 威龍
# 威嚴
# 宣布
# 宣示
# 宣告
# 宣揚
# 宣誓
# 宣誓保護
# 宣導
# 客氣
# 客觀
# 客觀了解
# 客觀性
# 封王
# 封后
# 幽默
# 幽默感
# 度過難關
# 建功
# 建立互信
# 建立共識
# 建全
# 建言
# 建定
# 建設性
# 建造
# 建構
# 建請
# 建築
# 建議
# 建議書
# 很cool
# 很了解
# 很大
# 很大發展空間
# 很大幫助
# 很大關係
# 很少不
# 很可以
# 很可以理解
# 很可能
# 很正常
# 很用心
# 很光榮
# 很多
# 很多優秀
# 很好
# 很好地
# 很好發展的契機
# 很有分量
# 很有可能
# 很有信心
# 很有看頭
# 很有創意
# 很有意義
# 很有機會
# 很有興趣
# 很有幫助
# 很自然地
# 很努力
# 很希望
# 很快
# 很快地
# 很投入
# 很受歡迎
# 很幸運
# 很旺
# 很明智
# 很欣賞
# 很長
# 很便宜
# 很炫
# 很負責任
# 很重要
# 很重視
# 很容易
# 很特別
# 很高
# 很高的評價
# 很高興
# 很夠
# 很夠用
# 很強
# 很清楚
# 很爽
# 很紮實
# 很喜歡
# 很愉快
# 很棒
# 很渴望
# 很開心
# 很順暢
# 很羡慕
# 很想
# 很愛
# 很會
# 很罩
# 很過癮
# 很像
# 很漂亮
# 很滿意
# 很精準
# 很酷
# 很燙
# 很篤定
# 很瞭解
# 很簡單
# 很穩
# 很驕傲
# 待人如友
# 待加強
# 待完成
# 待命
# 後來居上
# 後來居上優勢
# 後勁
# 後勁十足
# 後勢看好
# 思想性
# 思慮周延
# 急升
# 急待澄清
# 急迫性
# 急起直追
# 急欲
# 急欲了解
# 急速發展
# 急著處理
# 急漲
# 急劇升高
# 急難救助
# 恍然大悟
# 恰可
# 恰好
# 恰當
# 恰當地
# 恢復元氣
# 恢復準頭
# 恆久
# 恆久不變
# 恆心
# 恃強
# 恃強屈服
# 恬靜
# 恪守
# 恪遵
# 拜訪
# 拜讀
# 按此
# 按規定
# 按部就班
# 按照
# 拭目以待
# 持久
# 持有
# 持盈保泰
# 持穩
# 持續加大
# 持續加強
# 持續成長
# 持續強勁
# 持續提升
# 持續提昇
# 持續發熱
# 持續發燒
# 持續發燙
# 持續進行
# 持續增加
# 持續履行
# 指日可待
# 指出
# 指向
# 指定適用
# 指明
# 指派
# 指揮
# 指揮監督
# 指標
# 指標意義
# 指導方針
# 指證
# 拯救
# 挑對
# 挑燈夜戰
# 挑選
# 故意提醒
# 施力
# 施予
# 施展
# 施展抱負
# 施展鐵腕
# 施恩
# 施捨
# 施捨慷慨
# 既定
# 春天
# 是可行的方向
# 是好
# 是男子漢
# 是男子漢、大丈夫
# 是明智之舉
# 是指
# 是為了
# 是造成
# 柔和
# 柔性
# 柔性化
# 柔情
# 柔軟
# 柔雅
# 柔順
# 柔滑
# 架設
# 架設妥當
# 架構
# 查明
# 查核
# 查證
# 查證屬實
# 查驗
# 柳眉
# 殆可斷言
# 殆無疑問
# 洋房
# 洋洋
# 洋洋灑灑
# 洋溢
# 洋溢著
# 洋溢著幸福
# 流入
# 流行
# 流利
# 流動性
# 流動率高
# 流通
# 流暢
# 流露
# 津津樂道
# 津貼
# 洞燭機先
# 洞識
# 洗心革面
# 洗刷
# 洗禮
# 活力
# 活化
# 活水
# 活得很好
# 活著
# 活像
# 活潑
# 活潑地
# 活蹦亂跳
# 活躍
# 派上用場
# 派上場
# 派出
# 派往
# 為了
# 為之一振
# 為之瘋狂
# 為民服務
# 為民表率
# 為多
# 為此一戰
# 為快
# 為求
# 為佳
# 為使
# 為的是
# 為虎添翼
# 為時太早
# 為能
# 為高
# 為善
# 為傲
# 為榮
# 為懷
# 炯炯有神
# 狠角色
# 珍本
# 珍奇
# 珍重
# 珍惜
# 珍稀
# 珍貴
# 珍愛
# 珍饈
# 甚巨
# 甚多
# 甚有過之
# 甚佳
# 甚具
# 甚為關切
# 甚感高興
# 甚鉅
# 界定
# 疥
# 皆大歡喜
# 皆受惠
# 皆捷
# 皆勝
# 皆蒙其利
# 盈利
# 盈盈
# 盈餘
# 省了
# 省掉
# 省錢
# 相互
# 相互支援
# 相互探視
# 相互尊重
# 相互輝映
# 相去不遠
# 相去無幾
# 相似
# 相助
# 相容
# 相挺
# 相配合
# 相提並論
# 相當一致
# 相當大
# 相當大的貢獻
# 相當不錯
# 相當方便
# 相當正面
# 相當共識
# 相當多
# 相當好
# 相當安定
# 相當成功
# 相當有利
# 相當罕見
# 相當於
# 相當肯定
# 相當近
# 相當看好
# 相當重要
# 相當高
# 相當強勁
# 相當清楚
# 相當尊重
# 相當進展
# 相當順利
# 相當搶手
# 相當確定
# 相當激烈
# 相當幫助
# 相當豐富
# 相當穩定
# 相當關注
# 相對強勢
# 相對提高
# 相稱
# 相濡以沫
# 相關
# 相關服務
# 相繼
# 看上眼
# 看中
# 看出
# 看出端倪
# 看好
# 看似
# 看為
# 看重
# 看個過癮
# 看得出
# 看得出來
# 看漲
# 看齊
# 看頭
# 看顧
# 盼其
# 盼其成功
# 盼到
# 盼望
# 盼奪
# 研判
# 研究
# 研建
# 研討
# 研商
# 研習
# 研發
# 研發成功
# 研議
# 祈求
# 祈福
# 祈禱
# 祇要
# 科技創新
# 科學性
# 穿針引線
# 穿梭
# 突出
# 突出表現
# 突破性
# 突破僵局
# 突圍
# 突顯
# 紅利
# 紅潤
# 紅翻天
# 紀念
# 紀念碑
# 紀錄保持
# 約僱
# 美化
# 美名
# 美好
# 美妙
# 美事
# 美味
# 美的事物
# 美的音樂
# 美食在前
# 美國英雄
# 美景
# 美善
# 美感
# 美夢
# 美夢成真
# 美滿
# 美貌
# 美德
# 美麗
# 美譽
# 美艷
# 美豔
# 耐力好
# 耐久
# 耐心
# 耐心等候
# 耐用
# 耐性
# 耐看
# 耐勞
# 耐磨
# 背書
# 致力
# 致力完成
# 致力於
# 致力於維護
# 致力發展
# 致力鞏固
# 致力擴大
# 致力辯解
# 致有
# 致勝
# 致勝之道
# 致勝安打
# 致勝球
# 致勝球多
# 致勝關鍵
# 致富
# 致賀
# 致意
# 致敬
# 致謝
# 苦口婆心
# 苦修
# 苦盡甘來
# 若成立
# 若能
# 茂盛
# 英明
# 英俊
# 英勇
# 英傑
# 英雄
# 英雄人物
# 英雄之舉
# 英雄出少年
# 英雄式
# 茁壯
# 茁壯成長
# 茁長
# 要大
# 要大得多
# 要件
# 要有
# 要求嚴格
# 要角
# 要取得
# 要注意
# 要爭取
# 要負責任
# 要拿
# 要符合
# 要訪問
# 要緊
# 要衝
# 要贏
# 計畫
# 計畫發行
# 計畫會晤
# 計劃進軍
# 訂出
# 訂在
# 訂有
# 訂定
# 訂購
# 貞潔
# 負全責
# 負有
# 負有義務
# 負起
# 負起更大責任
# 負起責任
# 負責任
# 負責完成
# 負責認真
# 負責調查
# 負責擬制
# 負最終責任
# 迫不急待
# 迫切需求
# 重大功績
# 重大成就
# 重大突破
# 重大勝利
# 重大進展
# 重大意義
# 重大幫助
# 重大變革
# 重大讓步
# 重心
# 重生
# 重申
# 重任在身
# 重回
# 重於
# 重返
# 重返榮耀
# 重返賽場
# 重建
# 重拾
# 重要
# 重要一環
# 重要力量
# 重要地位
# 重要成果
# 重要角色
# 重要性
# 重要的地位
# 重要的角色
# 重要的課題
# 重要指標
# 重要政策
# 重要現場
# 重要課題
# 重要議題
# 重重圍觀
# 重振士氣
# 重振雄風
# 重振旗鼓
# 重砲
# 重起爐灶
# 重現
# 重掌
# 重登
# 重量級
# 重開
# 重開談判
# 重新
# 重新出發
# 重新計票
# 重新展開
# 重新站起
# 重新規劃
# 重新開放
# 重新運作
# 重新調整
# 重新檢討
# 重義
# 重劃
# 重聚
# 重聚一堂
# 重整
# 重頭戲
# 重獲
# 重獲自由
# 重點工作
# 重鎮
# 降至最低
# 降低勞動成本
# 降低緊張
# 面子十足
# 面帶微笑
# 面臨了
# 革新
# 韋成長
# 音樂
# 風平浪靜
# 風光
# 風光上路
# 風和日麗
# 風采
# 風度
# 風度絕佳
# 風風光光
# 風捲殘雲
# 風景如畫
# 風華
# 風華再現
# 風雲人物
# 風雲再現
# 風塵僕僕
# 風範
# 風險較低
# 風險轉小
# 飛毛腿
# 飛往
# 飛抵
# 飛黃騰達
# 飛彈
# 飛彈專家
# 首先
# 首先使用
# 首次
# 首見
# 首屈一指
# 首肯
# 首度
# 首度參加
# 首要目標
# 首要優先選擇
# 首倡
# 首席
# 首傑
# 首勝
# 首開先河
# 首須注意
# 首奪
# 首選
# 乘勝追擊
# 倍增
# 俯仰無愧
# 倖免
# 值得
# 值得一提
# 值得一試
# 值得正視
# 值得投資
# 值得肯定
# 值得信賴
# 值得紀念
# 值得重視
# 值得留意
# 值得崇拜
# 值得接受
# 值得尊重
# 值得尊敬
# 值得期待
# 值得稱讚
# 值得擁有
# 值得嚮往
# 值得關切
# 值得關注
# 值得觀察
# 值得讚美
# 值得讚揚
# 值勤
# 值錢
# 借用
# 借重
# 借鏡
# 倚重
# 倒是
# 俱佳
# 倡言
# 倡導
# 倡議
# 個人魅力
# 修好
# 修長
# 修訂
# 修復
# 倫理
# 兼有
# 兼而有之
# 兼容並蓄
# 兼優
# 兼顧
# 凌厲
# 凌駕
# 准許
# 剖析
# 剛出爐
# 剛猛
# 剛毅
# 原因無他
# 原定
# 原則
# 原是
# 原訂
# 原諒
# 原諒。
# 哲人
# 唆使
# 套用
# 娛樂
# 家喻戶曉
# 容光
# 容光煥發
# 容易
# 容易親近
# 展示了
# 展翅高飛
# 展翅高翔
# 展望
# 展現
# 展現了
# 展現友善
# 展現球后風範
# 展現善意
# 展現實力
# 展露
# 峰迴路轉
# 席捲
# 席捲高壇
# 師出有名
# 師法
# 恭候
# 恭喜
# 恭賀
# 恭敬
# 恭維
# 恭請
# 恩惠
# 恩寵
# 息息相關
# 悟出
# 悔改
# 悔悟
# 悅耳
# 拿下
# 拿下冠軍
# 拿下勝利
# 拿下勝投
# 拿分寸
# 拿手
# 拿手好戲
# 拿出
# 拿到冠軍
# 拿冠軍
# 挾著
# 振作
# 振振有詞
# 振振有辭
# 振衰起敝
# 振奮
# 振興
# 振興經濟
# 振臂歡呼
# 捉住商機
# 挺住
# 挺身
# 挺身而出
# 挺身協助
# 挺身聲擾
# 挺進
# 捐款
# 捐給
# 捐輸
# 捐贈
# 捐獻
# 挽回
# 挽救
# 捍衛
# 效忠
# 效果更加顯著
# 效法
# 效益較好
# 效能
# 效率
# 料將
# 料得到
# 料想
# 時人牙慧
# 時間
# 時勢所趨
# 時髦
# 時機
# 時機成熟
# 時機絕佳
# 時機適宜
# 晉入
# 晉升
# 晉身
# 晉身成為
# 晉級
# 晉級決賽
# 校訂
# 核心
# 核心準則
# 核定
# 根本
# 根本是
# 根本原則
# 根植
# 根據
# 格外珍惜
# 格外重要
# 格外神勇
# 格外僅慎
# 格外激列
# 格外興奮
# 格所珍惜
# 殊榮
# 殉國
# 殷切
# 殷盼
# 氣定神閒
# 氣氛平和
# 氣氛良好
# 氣氛和諧
# 氣氛熱烈
# 氣度
# 氣度從容
# 氣派
# 氣勢
# 氣勢正旺
# 氣勢如虹
# 氣勢很旺
# 氣勢凌人
# 氣勢驚人
# 浪漫
# 浪潮
# 消退
# 消遣
# 浮現
# 浴火鳳凰
# 浩大
# 浩然
# 浩瀚
# 特大
# 特出
# 特立獨行
# 特地
# 特地前往
# 特色
# 特別好
# 特別安排
# 特別保護
# 特別前往
# 特別是
# 特別突出
# 特別重要
# 特別強調
# 特別推出
# 特別感謝
# 特別徵詢
# 特別慰問
# 特別適合複製
# 特快車
# 特佳
# 特定
# 特殊
# 特級
# 特強
# 特許
# 特質
# 留下
# 留下來
# 留下許多
# 留心
# 留名
# 留住
# 留神
# 留情
# 留意
# 留戀
# 疾呼
# 疼愛
# 疼愛地
# 益加顯示
# 益形
# 益處
# 益增
# 益趨
# 益顯貼切
# 真了得
# 真切
# 真心
# 真心的感謝
# 真心誠意
# 真正
# 真正安心
# 真正考驗
# 真正重要
# 真正擺脫
# 真好
# 真希望
# 真的是
# 真是如此
# 真能
# 真理
# 真進了
# 真愛
# 真誠
# 真誠執行
# 真實
# 真摯
# 真確
# 砸下
# 砸下巨資
# 破天荒
# 破冰之旅
# 破門而入
# 破紀錄
# 破獲
# 破鏡重圓
# 砲火又發威
# 祟拜
# 神功護體
# 神色從容
# 神似
# 神志正常
# 神志清明
# 神技
# 神來一推
# 神奇
# 神采奕奕
# 神勇
# 神勇出擊
# 神威
# 神氣活現
# 神情愉悅
# 神通廣大
# 神智健全
# 神童
# 神準
# 神聖
# 神蹟
# 祝賀
# 祝福
# 秩序
# 窈窕
# 站出來
# 站在
# 站在他這邊
# 笑口常開
# 笑兮兮
# 笑死囉
# 笑容
# 笑勒
# 笑著擁抱
# 笑傲
# 笑靨
# 素有
# 素有淵源
# 索取
# 索賠
# 索償促進
# 純正
# 純真
# 純淨
# 純粹愛好
# 純潔
# 純熟
# 納入
# 耿直
# 胸有成竹
# 脈絡可循
# 能充分理解
# 能生產
# 能吃苦耐勞
# 能有
# 能免除
# 能求
# 能言善道
# 能使
# 能供應
# 能保住
# 能為
# 能做到
# 能堅守
# 能夠依
# 能夠理解
# 能得
# 能從容轉型
# 能符合
# 能超越
# 能幹
# 能落實
# 能跟進
# 能奪標
# 能實行
# 能與
# 能應付
# 能懂
# 能瞭解
# 能體會
# 能讓
# 虔信
# 虔敬
# 虔誠
# 衷心
# 衷心地
# 衷心祝福
# 衷心期盼
# 記取
# 記憶猶新
# 討人喜歡
# 討人歡喜
# 討公道
# 討回公道
# 討喜
# 討論聯手推出
# 訓練
# 訓練有素
# 財產
# 貢獻
# 貢獻良多
# 起自
# 起色
# 起作用
# 起步
# 起身鼓掌
# 起於
# 起勁
# 起飛
# 送上
# 送出
# 送去
# 送交
# 送至
# 送到
# 送往
# 送達
# 送禮
# 逆轉攻勢
# 逆轉秀
# 逆轉勝
# 逆轉稱王
# 迷人
# 迷人之處
# 迷人的美
# 迷戀
# 迴響
# 追了上來
# 追上
# 追及
# 追加
# 追平
# 追平分
# 追成
# 追求成功
# 追求完美
# 追求更好
# 追求更高
# 追求理想
# 追究到底
# 追到
# 追根究底
# 追討
# 追高
# 追尋
# 配合修正
# 酌予支應
# 針對
# 閃閃巨星
# 閃逝著
# 閃爍
# 陣容
# 馬上
# 馬上面臨
# 馬上就想
# 馬上開始
# 馬首是瞻
# 高人一等
# 高才
# 高手
# 高水準
# 高出
# 高出甚多
# 高出許多
# 高成就
# 高而富
# 高妙
# 高技術
# 高呼
# 高尚
# 高居
# 高居榜首
# 高招
# 高於標準
# 高昂
# 高枕無憂
# 高的肯定
# 高品質
# 高度成長
# 高度重視
# 高度評價
# 高度凝聚力
# 高度興趣
# 高峰
# 高挺
# 高級
# 高高興興
# 高高舉起
# 高唱
# 高崇
# 高得多
# 高得驚人
# 高掛
# 高球明星
# 高處
# 高就
# 高貴
# 高貴優雅
# 高超
# 高階
# 高雅
# 高達
# 高談闊論
# 高論
# 高踞
# 高興極了
# 高舉
# 高點可期
# 高瞻遠矚
# 高額
# 鬥士
# 鬥志
# 鬥志高昂
# 鬥性堅強
# 倜儻
# 凄婉
# 挹注
# 挹注入
# 紓困計畫
# 紓解
# 紓緩
# 乾脆
# 乾淨
# 停火
# 停戰
# 假以時日
# 假使
# 做出
# 做出決議
# 做好
# 做好準備
# 做到
# 做到了
# 做為研判
# 做得到
# 做準備
# 做證
# 偉大
# 偉大成就
# 健全
# 健壯
# 健朗
# 健康
# 健康化
# 健碩
# 偶然發生
# 偶像
# 偵辦
# 側重
# 偏好
# 偏重
# 偏愛
# 偏屬
# 務必
# 務使
# 務期
# 務實
# 勘查
# 動人
# 動力相當明顯
# 動用
# 動容
# 動機
# 參加踴躍
# 參考
# 參採
# 參與構思
# 參戰
# 參據
# 參選
# 參賽
# 參觀
# 參觀比較
# 商討
# 商業往來
# 商路
# 商請
# 商機
# 商機豐厚
# 商機驚人
# 問心無愧
# 問世
# 問鼎
# 唯一
# 唯一可靠
# 唯有大膽西進、南向
# 唯我獨贏
# 唯實論
# 售價僅
# 國民黨
# 國際模範生
# 堅守立場
# 堅忍
# 堅決
# 堅決要求
# 堅固
# 堅固耐用
# 堅定
# 堅定不移
# 堅定化
# 堅定共識
# 堅定地
# 堅定承諾
# 堅持不懈
# 堅持完成
# 堅持保留
# 堅挺
# 堅強
# 堅強信念
# 堅硬
# 堅硬無比
# 堅絕
# 堅韌
# 堅實
# 堅稱
# 堅毅
# 堅穩
# 堆砌
# 基本
# 基石
# 基於道義
# 堂而皇之
# 堂皇
# 執掌
# 執著
# 培育
# 培訓
# 夠大
# 夠水準
# 夠味
# 夠風光
# 夠格
# 夠資格
# 寄希望
# 寄託
# 密切
# 密切注意
# 密切結合
# 密切溝通
# 密切關注
# 專人護送
# 專心
# 專攻
# 專注
# 專美於前
# 專家
# 專責
# 專業化
# 專職負責
# 將了解
# 將分占
# 將以
# 將代表
# 將出現
# 將功贖罪
# 將可
# 將可以
# 將可如期
# 將可利用
# 將可使用
# 將可能
# 將可參加
# 將可獲得
# 將瓜分
# 將由
# 將交接
# 將因此受惠
# 將在
# 將如期
# 將成
# 將成立
# 將成為
# 將有
# 將有助益
# 將有機會
# 將自
# 將呈
# 將形成
# 將改為
# 將更激烈
# 將走強
# 將依法
# 將使
# 將到
# 將和
# 將往
# 將於
# 將近
# 將促
# 將宣示
# 將建立
# 將建議
# 將是
# 將派遣
# 將為
# 將要
# 將納入
# 將討論
# 將配合
# 將高達
# 將做為
# 將參加
# 將帶來
# 將帶領
# 將接受
# 將授予
# 將採取
# 將牽動
# 將訪問
# 將設置
# 將提供
# 將發表
# 將發動
# 將會
# 將會大增
# 將會建議
# 將會是
# 將會認真研究
# 將補足
# 將跟著
# 將對
# 將盡力
# 將盡快
# 將管理
# 將維持
# 將與
# 將領到
# 將增加
# 將調查
# 將儘快
# 將舉行
# 將邀請
# 將釐清
# 將繼續
# 將贏得
# 崇尚
# 崇拜
# 崇高
# 崇高使命
# 崇高理想
# 崇揚
# 崇揚正面
# 崇隆
# 崇敬
# 崛起
# 常見
# 常是
# 常常
# 常理
# 常勝
# 帶入
# 帶回
# 帶好
# 帶有靈感
# 帶些
# 帶來和平
# 帶來挑戰
# 帶來福氣
# 帶來歡樂
# 帶動
# 帶動了
# 帶給
# 帶進
# 帶領風騷
# 康健
# 康莊大道
# 強一些
# 強人
# 強力手段
# 強力支持
# 強力攻勢
# 強力建議
# 強大
# 強大信心
# 強化了
# 強心劑
# 強加於
# 強打火力
# 強打如林
# 強而有力
# 強行帶走
# 強行帶往
# 強壯
# 強投
# 強攻
# 強制轉換
# 強於
# 強勁
# 強悍
# 強烈的支持
# 強烈建議
# 強烈要求
# 強烈暗示
# 強烈關切
# 強健
# 強國
# 強盛
# 強棒
# 強韌
# 強勢
# 強勢貨幣
# 強勢登場
# 強過
# 強過頭
# 強調了
# 強權
# 彬彬
# 彬彬有禮
# 得人心
# 得力
# 得大獎
# 得分
# 得心應手
# 得手
# 得主
# 得以
# 得以加入
# 得以倖免
# 得以發展
# 得以團聚
# 得以適用
# 得先
# 得自
# 得利
# 得志
# 得依
# 得來
# 得到改善
# 得到最大好處
# 得到落實
# 得宜
# 得知
# 得為
# 得要領
# 得兼
# 得接受
# 得勝
# 得意揚揚
# 得過
# 得對
# 得維持
# 得獎
# 得獎最多
# 得償
# 得體
# 從一而終
# 從不諱言
# 從中得利
# 從中獲利
# 從天而降
# 從未放棄
# 從良
# 從事改革
# 從容
# 從容不迫
# 從速
# 從速修正
# 從實
# 從寬
# 從寬認定
# 從優
# 從優撫卹
# 悠久
# 悠哉
# 悠游
# 情不自禁
# 情投意合
# 情況相符
# 情深
# 情理兼顧
# 情願
# 捲土重來
# 探望
# 探親團聚
# 探囊取物
# 接收
# 接見
# 接受殊榮
# 接近完成
# 接軌
# 接班人
# 接通
# 接連
# 接掌
# 接管
# 接踵而來
# 接濟
# 接獲
# 接觸
# 接觸交流
# 接續
# 捷足先登
# 捷徑
# 捷報
# 捧回
# 捧走
# 捧來面前
# 捧到
# 捧場
# 捧過
# 掩面而泣
# 掩飾太平
# 掃進
# 掃黃
# 掛帥
# 掛牌上市
# 推力
# 推出
# 推向
# 推行
# 推估
# 推波助瀾
# 推派
# 推展
# 推崇
# 推崇備至
# 推理
# 推測
# 推進
# 推敲
# 推演
# 推算
# 推廣
# 推論
# 推銷
# 推選
# 推舉
# 推薦
# 掄元
# 授予
# 授與
# 採行
# 採取
# 採取行動
# 採信
# 採納
# 採訪邀約
# 排名如此高的對手
# 排名前茅
# 排名首位
# 排名第一
# 排定
# 排除萬難
# 排進
# 排萬難
# 掀起
# 掀起熱潮
# 捨我其誰
# 救了
# 救人為先
# 救火
# 救世主
# 救出
# 救平
# 救回
# 救回來
# 救助
# 救災
# 救到
# 救起
# 救國
# 救援
# 救援成功
# 救濟
# 救難
# 救護
# 教養
# 啟用
# 啟示
# 啟動
# 啟發
# 啟發想像力
# 啟程
# 啟程衛冕
# 敏悟
# 敏捷
# 敏捷地
# 敏銳
# 敏銳的感覺力
# 斬釘截鐵
# 斬獲
# 旋即
# 旋風
# 望子成龍
# 望而興嘆
# 望其項背
# 欲求大熾
# 欲達成
# 欲與
# 殺出重圍
# 殺進
# 毫不含糊
# 毫不畏懼
# 毫不緊張
# 毫不諱言
# 毫無止境
# 毫無止境地
# 毫無阻礙
# 毫無意外
# 毫無疑問
# 毫無隱諱
# 毫無懷疑
# 涼快
# 涼爽
# 涼爽的空氣
# 淳樸
# 添一佳話
# 添了
# 添上一筆
# 添加
# 添殊榮
# 添新
# 添增助力
# 淺顯
# 清白
# 清白勝選
# 清秀
# 清和
# 清明
# 清芬
# 清朗
# 清脆
# 清高
# 清清楚楚
# 清理
# 清理門戶
# 清晰
# 清越
# 清雅
# 清楚
# 清楚地
# 清楚易懂
# 清澈
# 清潔
# 清醒
# 清譽
# 清歡
# 淋漓盡致
# 淑女
# 涵蓋
# 淘金
# 淘金獲利
# 淘氣
# 深入了解
# 深入討論
# 深切
# 深切注意
# 深化
# 深化發展
# 深沈
# 深具
# 深具信心
# 深具影響力
# 深受鼓舞
# 深知
# 深表同意
# 深表樂觀
# 深信
# 深思熟慮
# 深重
# 深情
# 深深抓住
# 深感欣慰
# 深愛
# 深遠
# 深遠影響
# 深廣
# 深慮
# 深謀遠慮
# 深諳
# 淨化
# 淨素
# 淬煉
# 爽口
# 爽快
# 爽朗
# 牽動
# 猛打帶動
# 猛吹口哨
# 猛追
# 猛然飛出
# 猛進
# 率先
# 率先響應
# 率同
# 率直
# 率直地
# 率真
# 率隊
# 率領
# 球王
# 球功
# 球運鴻通
# 理所當然
# 理直氣壯
# 理智
# 理想
# 理想化
# 理當
# 理解
# 理應
# 現代化
# 現行
# 現曙光
# 甜姐兒
# 甜美
# 甜甜蜜蜜
# 甜滋滋
# 甜蜜
# 甜頭
# 產生
# 產生交集
# 產乳量更高
# 產量多
# 產業升級
# 略好於
# 略有起色
# 略有進展
# 略高
# 略帶城府
# 略勝
# 略誘
# 略增
# 畢生目標
# 畢竟都是
# 異口同聲
# 異軍突起
# 疏通
# 疏導
# 痊癒
# 痊癒、撫平
# 盛大
# 盛大歡迎
# 盛名
# 盛年
# 盛事
# 盛況
# 盛開
# 盛讚
# 眷戀
# 眾人仰望
# 眾人矚目
# 眾所期待
# 眾所週知
# 眾所熟知
# 眾所矚目
# 眾望所歸
# 眼光放遠
# 祥和
# 票房保證
# 票選產生
# 移送
# 移轉
# 第9種子身分
# 第一
# 第一人
# 第一人選
# 第一手消息
# 第一份
# 第一名
# 第一好手
# 第一次
# 第一把交椅
# 第一步
# 第一流
# 第一要務
# 第一個
# 第一時間
# 第一高
# 第一高手
# 第一頭
# 第一優先
# 符合要求
# 符合資格
# 統一
# 統計
# 統籌承辦
# 紮實
# 細心
# 細密
# 細緻
# 細緻優雅
# 細膩
# 紳士
# 組建
# 累積
# 累積了
# 終生成就
# 終身成就
# 終使
# 終於
# 終於等到
# 終致
# 終能
# 終得解放
# 終歸是
# 脫困
# 脫俗
# 脫胎換骨
# 脫帽致敬
# 脫穎而出
# 莫不
# 莫過於
# 莊重
# 莊嚴
# 處理好
# 處理得宜
# 處理善後
# 被同意
# 被判定
# 被判處
# 被判賠
# 被注視
# 被看好
# 被迫開放
# 被強迫
# 被喜愛
# 被發現
# 被視為
# 被愛
# 被稱為
# 被認同
# 被認為
# 被賦予
# 被選為
# 被譽為
# 規矩
# 規畫
# 規劃
# 規模最大
# 規模較大
# 規模擴大
# 規避風險
# 訪問
# 許可
# 許多好手
# 許多佳績
# 設立
# 設立軍
# 設法
# 設法改善
# 設法取得
# 設置
# 責任心
# 責任重大
# 責任感
# 貫穿
# 貫徹
# 貫徹執行
# 貨暢其流
# 赦免
# 這麼多
# 這麼好
# 這麼快
# 這樣做非常合理
# 通用
# 通向
# 通吃
# 通行
# 通行無阻
# 通往
# 通知
# 通常
# 通暢
# 通關
# 逗得大樂
# 連10年獲分區冠軍
# 連二接三
# 連下
# 連五莊
# 連冠
# 連拿
# 連根拔起
# 連帶
# 連得
# 連莊
# 連連勝利
# 連勝
# 連結
# 連搶
# 連署
# 連過三關
# 連奪
# 連摘
# 連稱殊榮
# 連戰皆捷
# 連闖
# 連闖四關
# 連繫
# 連贏
# 連贏四
# 連續
# 連續安打
# 連續拿下
# 連霸
# 速戰速決
# 逐利
# 逐步
# 逐步上揚
# 逐步交出
# 逐步走強
# 逐步推展
# 逐步推動
# 逐步落實
# 逐步實現
# 逐步撤除
# 逐步確立
# 逐步趨堅
# 逐步擴大
# 逐步釋出
# 逐冠
# 逐漸
# 逐漸上揚
# 逐漸升高
# 逐漸出現
# 逐漸回升
# 逐漸好轉
# 逐漸成為
# 逐漸走強
# 逐漸拉平
# 逐漸恢復
# 逐漸消失
# 逐漸強大
# 逐漸習慣
# 逐漸發展
# 逐漸進行
# 逐漸開始
# 逐漸解凍
# 逐漸增加
# 逐漸調整
# 逐漸適應
# 逐漸顯現
# 造成
# 造詣
# 造福
# 造福社會
# 透明
# 透明化
# 透明度更高
# 透過
# 部署
# 都可
# 都可以
# 都可能
# 都在
# 都有
# 都有可能
# 都希望
# 都是
# 都能
# 都記住
# 都會
# 都會有
# 都滿意
# 都需要
# 都應
# 陪同
# 陪伴
# 陪著
# 陪償
# 陳請
# 陸續
# 陸續出發
# 陸續加入
# 陸續接到
# 陸續團圓
# 陶醉
# 雀屏中選
# 雀躍
# 頂尖
# 頂尖高手
# 頂峰
# 頂點
# 備妥
# 備受
# 備受外界期待
# 備受肯定
# 備受鼓舞
# 備受關注
# 備受矚目
# 傑出
# 傑出人物
# 傑出地
# 傑出表現
# 傑作
# 最了解
# 最上
# 最大成就
# 最大利益
# 最大努力
# 最大受益
# 最大的誠意
# 最大保障
# 最大挑戰
# 最大規模
# 最大勝幅
# 最大誠意
# 最大領先
# 最大熱門
# 最大獲勝
# 最大關鍵
# 最大贏家
# 最少局數
# 最方便
# 最主要
# 最令人難忘
# 最可能
# 最巨
# 最先
# 最先進
# 最多
# 最多安打
# 最多次
# 最多勝
# 最好
# 最好地
# 最好的方法
# 最好是
# 最好結果
# 最好照顧
# 最好機會
# 最年輕
# 最成功
# 最有
# 最有可能
# 最有利
# 最有希望
# 最有威望
# 最有效
# 最有效地
# 最有效發揮
# 最有氣勢
# 最有殺氣
# 最有意義
# 最有資格
# 最有價值
# 最有價值球員
# 最有影響力
# 最有權勢
# 最完美
# 最希望
# 最快
# 最快速
# 最佳
# 最佳示範
# 最佳成績
# 最佳男主角
# 最佳拍檔
# 最佳勁旅
# 最佳指標
# 最佳紀錄
# 最佳球員
# 最佳場所
# 最佳復出
# 最佳新人
# 最佳新人榮銜
# 最佳新秀
# 最佳機會
# 最具
# 最具主宰力
# 最具出口競爭優勢
# 最具后望
# 最具成效
# 最具有
# 最具傳統
# 最具影響力
# 最具優勢
# 最具權威
# 最具體
# 最受注目
# 最受眾人矚目
# 最受期待
# 最受歡迎
# 最受矚目
# 最怏
# 最長
# 最便宜
# 最看好
# 最盼望
# 最突出
# 最紅
# 最美麗
# 最負盛名
# 最重大
# 最重要
# 最風光
# 最首要
# 最值得
# 最容易
# 最根本
# 最特別
# 最能適應
# 最高
# 最高明
# 最高紀錄
# 最高峰
# 最高得分紀錄
# 最高榮耀
# 最高榮譽
# 最高領導
# 最高薪
# 最高權力
# 最偉大
# 最強
# 最強大
# 最強勢
# 最強實質作用
# 最接近
# 最深
# 最深刻
# 最理想
# 最符合
# 最終夢想
# 最被看好
# 最頂峰
# 最傑出
# 最富
# 最富影響力
# 最惠國待遇
# 最期盼
# 最棒
# 最短局數
# 最貴
# 最進步
# 最雄厚
# 最想
# 最想成為
# 最想看
# 最愛
# 最搶手貨
# 最搶眼
# 最新
# 最新公布
# 最新完成
# 最新發展
# 最會賺錢
# 最節省
# 最該
# 最實際
# 最漂亮
# 最精采
# 最需要
# 最厲害
# 最寬
# 最熱門
# 最熱烈
# 最適當地
# 最靠近
# 最優
# 最優先
# 最優先推動案
# 最優先項目
# 最優秀
# 最優厚
# 最優異
# 最應
# 最燦爛
# 最鍾愛
# 最豐收
# 最關心
# 最關鍵
# 最難忘
# 最難得
# 最嚴密
# 最耀眼
# 最顯著
# 凱旋
# 創下
# 創立
# 創立者
# 創作
# 創佳績
# 創空前紀錄
# 創紀錄
# 創設
# 創造
# 創造力
# 創造出
# 創造性
# 創意
# 創新
# 創新高
# 創舉
# 勝仗
# 勝出
# 勝任
# 勝利
# 勝利在望
# 勝利在握
# 勝利作收
# 勝利的號角
# 勝投
# 勝投在握
# 勝券在握
# 勝於
# 勝差
# 勝基
# 勝率優勢
# 勝幅
# 勝訴
# 勝訴希望
# 勝過
# 勝算
# 勝算較大
# 勝選
# 博取
# 博得
# 博得滿堂采
# 博愛
# 博愛者
# 喧騰一時
# 喊出
# 喊得響亮
# 喝采
# 喝彩
# 喘一口氣
# 喜不自禁
# 喜出望外
# 喜用
# 喜悅
# 喜氣
# 喜氣洋洋
# 喜酒
# 喜感
# 喜愛
# 喜愛機會
# 喜極而泣
# 喜嘗
# 喜劇
# 喜慶
# 喜歡
# 單季最多
# 單純
# 單獨領先
# 喚回
# 圍觀
# 堪為
# 堪稱
# 報到支援
# 報恩
# 報喜
# 報答
# 報酬
# 奠下基礎
# 奠定勝基
# 奠基
# 奠基者
# 富有
# 富有魅力
# 富含
# 富足
# 富於
# 富於同情心
# 富於機智
# 富幽默感
# 富挑戰性
# 富強
# 富裕
# 富麗
# 富麗堂皇
# 富饒
# 寓意
# 尊長
# 尊重
# 尊重人
# 尊重現實
# 尊崇
# 尊貴
# 尊敬
# 尊敬人
# 尊榮
# 尊嚴
# 尋獲
# 就一定得
# 就可
# 就可以
# 就可解決
# 就有
# 就有能力
# 就事論事
# 就能
# 就能完成
# 就夠了
# 就得
# 就會
# 就緒
# 就範
# 幾乎
# 幾乎可說是
# 幾乎是
# 幾乎相同
# 幾乎掌握
# 幾乎等於
# 幾乎等於是
# 幾近
# 幾無瑕疵
# 復出
# 復活
# 復活之路
# 復原
# 復原迅速
# 復燃
# 循序漸進
# 悲憫
# 惠顧
# 愜意
# 愉快
# 愉快地
# 愉快地說
# 愉快封王
# 愉悅
# 掌兵符
# 掌政
# 掌控
# 掌理
# 掌握
# 掌握機先
# 掌管
# 掌聲
# 掌權
# 插上一腳
# 提升
# 提升效率
# 提出此議
# 提出建議
# 提名
# 提早
# 提早因應
# 提早規劃
# 提供
# 提供協助
# 提供建議
# 提供援助
# 提供適度救助
# 提昇
# 提建
# 提倡
# 提振
# 提高了
# 提高出口競爭力
# 提高品質
# 提議
# 提攜
# 握手言和
# 握手致意
# 握有
# 握有證據
# 揖讓而升下而飲
# 揭發真相
# 揭開
# 揭曉
# 援手
# 援用
# 援助
# 援救
# 揪出
# 換成
# 換取
# 揚名
# 揚名立萬
# 揚威
# 揚揚
# 揚揚自得
# 敞開
# 敞開大門
# 敦請
# 敢用
# 敢於承認
# 敢說
# 散播
# 斐然
# 斯文
# 普受讚揚
# 普遍
# 普遍化
# 晴朗
# 景仰
# 景氣
# 智力
# 智巧
# 智者
# 智慧
# 智慧之道
# 期使
# 期勉
# 期盼
# 期能
# 期望
# 期望更高
# 期望說服
# 期望獲勝
# 期許很高
# 期許高
# 朝向
# 朝服
# 朝著
# 朝陽升起
# 棒子發燙
# 棒棒精采
# 款待
# 欽佩
# 渡過難關
# 湧入
# 湧現
# 湧過
# 減免
# 減稅
# 渴求
# 渴求和平
# 渴盼
# 渴望
# 渴望獲得
# 滋潤
# 滋養
# 焦點
# 無一不是
# 無人能及
# 無人能擋
# 無不
# 無不以
# 無日無之
# 無比
# 無出其右
# 無可否認
# 無可厚非
# 無可指責
# 無可挑剔
# 無可責難
# 無可置辯
# 無污點
# 無刺激性
# 無法抗拒
# 無法取代
# 無阻
# 無非
# 無非是
# 無畏
# 無畏無懼
# 無重大疑問
# 無限上綱
# 無限制
# 無限商機
# 無害
# 無害處
# 無時無地不
# 無缺
# 無缺點
# 無庸
# 無庸置疑
# 無庸置疑地
# 無庸贅言
# 無異
# 無異狀
# 無異議
# 無惡意
# 無痛
# 無痛苦
# 無裂縫
# 無傷
# 無意外
# 無瑕
# 無瑕疵
# 無罪
# 無過
# 無過失
# 無疑
# 無疑地
# 無疑是
# 無疑問
# 無誤
# 無誤地
# 無障礙
# 無價
# 無慮
# 無憂無慮
# 無慾
# 無敵
# 無衝突
# 無懈可擊
# 無礙
# 無邊無際
# 無懼
# 無懼於
# 無懼無畏
# 無髒污
# 猶未為晚
# 猶如超人
# 畫上等號
# 痛快
# 痛快地
# 痛定思痛
# 登上
# 登門求教
# 登峰
# 登頂
# 登場
# 發出虎嘯
# 發出難得的真心話
# 發出警報
# 發布
# 發生
# 發光
# 發行
# 發育
# 發放
# 發威
# 發展
# 發展成熟
# 發展有利
# 發展迅猛
# 發展空間
# 發展潛力
# 發財
# 發財致富
# 發送
# 發現
# 發揮
# 發揮力量
# 發揮老薑威力
# 發揮助益
# 發揮效果
# 發揮應有的實力
# 發揮競爭實力
# 發揚
# 發達
# 發奮圖強
# 發願
# 發覺
# 盜壘成功
# 稍好
# 稍息
# 稍高
# 稍微揚升
# 稍感寬慰
# 稍獲滿足
# 稀少
# 稀有動物
# 稀奇
# 等同於
# 等到
# 等於宣佈
# 等於是
# 等待
# 等量齊觀
# 策動
# 策劃與推動
# 答允
# 答稱
# 答應
# 答謝
# 答覆
# 答辯
# 結盟
# 結緣
# 結識
# 絕大多數
# 絕大部分
# 絕不止此
# 絕不偏私
# 絕地大反攻
# 絕地反撲
# 絕妙
# 絕技
# 絕佳
# 絕非偶然
# 絕配
# 絕無風險
# 絕無虛假
# 絕無錯誤
# 絕對公平公正
# 絕對公道
# 絕對支持
# 絕對可以
# 絕對可以恢復
# 絕對可靠
# 絕對多數
# 絕對有必要
# 絕對有意
# 絕對服膺
# 絕對尊重
# 絕對會
# 絕對優勢
# 絕對應該
# 絕響
# 絡繹不絕
# 給予
# 給予幫助
# 給足
# 善心
# 善加利用
# 善用
# 善目
# 善良
# 善事
# 善念
# 善性
# 善於
# 善於經營
# 善待
# 善後
# 善神
# 善理
# 善理家
# 善終
# 善進
# 善意
# 善意回應
# 善業
# 善盡
# 善盡言責
# 善盡責任
# 善盡職責
# 善說服
# 善戰
# 善舉
# 善辯
# 舒服
# 舒解
# 舒暢
# 舒適
# 菁英
# 華麗
# 著力
# 著手
# 著手改善
# 著名
# 著重
# 著迷
# 著眼
# 著意
# 著想
# 著稱
# 著墨
# 著墨頗多
# 萌生
# 虛擬
# 裁決
# 裁定
# 裁編
# 視此為
# 視其為
# 視為
# 視察
# 視需要
# 評估
# 評選
# 評選為
# 評斷
# 証明
# 証實
# 証據
# 訴求
# 訴願
# 診斷
# 象徵著
# 貼切
# 貼近
# 貼補
# 貴重
# 貴氣
# 貴族
# 貴賓席
# 買入
# 越大
# 越大越好
# 越好
# 越有利
# 越見進步
# 越來越大
# 越來越多
# 越來越依賴
# 越來越重要
# 越來越高
# 越來越緊密
# 越是重要
# 越高
# 越過
# 越辦越好
# 越變越好
# 超人氣
# 超人氣魅力
# 超凡
# 超凡成就
# 超凡技術
# 超升
# 超水準
# 超出甚多
# 超好
# 超自然神技
# 超完美
# 超旺
# 超前
# 超前領先
# 超級
# 超級大贏家
# 超級巨星
# 超級明星
# 超級球星
# 超級新人
# 超級戰將
# 超高分
# 超強
# 超猛
# 超猛、超酷、超辣
# 超棒
# 超然
# 超越巔峰
# 超辣
# 超酷
# 趁早
# 趁著
# 週到
# 進一步
# 進而
# 進而合作
# 進而促進
# 進而謀求
# 進行協商
# 進行研究
# 進行研商
# 進行順利
# 進行溝通
# 進行補償
# 進行對話
# 進行確認
# 進行瞭解
# 進行辯護
# 進步
# 進決賽
# 進取
# 進取心
# 進軍
# 進展
# 進程
# 進階
# 進補
# 進駐指揮
# 量身打造
# 量身訂製
# 開化
# 開心
# 開心地
# 開出
# 開市
# 開打在即
# 開立
# 開成
# 開始交易
# 開始成形
# 開始刮起
# 開始和解
# 開始參與
# 開始啟用
# 開始統合
# 開始規劃
# 開始復甦
# 開始揣測
# 開始登基
# 開始進行
# 開始運作
# 開始鼓勵
# 開始實施
# 開放
# 開放自由
# 開明
# 開胡
# 開展
# 開朗
# 開張
# 開張大吉
# 開啟
# 開設
# 開通
# 開發
# 開源節流
# 開誠布公
# 開誠佈公
# 開路
# 開端
# 開盤
# 開導
# 開辦
# 開闊
# 開釋
# 開鑼
# 間歇
# 陽光普照
# 陽春全壘打
# 陽春砲
# 陽春彈
# 雅致
# 雅量
# 雅緻
# 雅觀
# 雄心
# 雄心壯志
# 雄厚
# 雄偉
# 雄踞
# 雄辯
# 集中
# 集中心力
# 集中注意
# 集中精神
# 集思廣益
# 集資
# 集體
# 順手
# 順利上路
# 順利如願
# 順利成功
# 順利完成
# 順利投入
# 順利取得
# 順利施行
# 順利展開
# 順利拿下
# 順利起步
# 順利起跑
# 順利執行
# 順利推行
# 順利推動
# 順利通過
# 順利登場
# 順利發行
# 順利進行
# 順利進展
# 順利會議
# 順利運作
# 順利過關
# 順利奪標
# 順利監督
# 順利確定
# 順利獲勝
# 順利舉行
# 順利闖關
# 順利贏得
# 順風車
# 順差
# 順眼
# 順當
# 順遂
# 順暢
# 順應
# 順應大趨勢
# 須以
# 須加強
# 須由
# 須在
# 須完成
# 須依
# 須知
# 須要
# 須配合
# 須將
# 須視
# 須調整
# 黃金
# 黃金時段
# 黃金陣容
# 黑馬
# 羡煞
# 亂中有序
# 傲人
# 傲人佳績
# 傲居
# 傲視
# 傲視國聯
# 傲視新秀
# 傲視群雄
# 傳出
# 傳來
# 傳奇人物
# 傳奇性
# 傳捷報
# 傳授
# 傳喚
# 傳達善意
# 僅在
# 僅具
# 僅是
# 僅能
# 僅慎
# 傾力
# 傾向認為
# 催化
# 催收
# 傷癒
# 募集
# 勤於
# 勤於練習
# 勤勉
# 勤奮
# 勤學
# 勢必大增
# 勢必更旺
# 勢必堅持
# 勢必會
# 勢在必行
# 勢在必得
# 勢如破竹
# 勢均力敵
# 勢所必然
# 勢所必須
# 勢所難免
# 勢氣如虹
# 勢將
# 匯率穩定
# 嗜好
# 圓夢
# 圓滿
# 圓滿成功
# 圓漪場
# 奧援
# 媲美
# 幹勁
# 廉明
# 廉價
# 廉潔
# 微妙
# 微笑
# 微微
# 意外輕鬆地
# 意在
# 意即
# 意志堅定
# 意志集中
# 意味深長
# 意味著
# 意指
# 意料中
# 意料中事
# 意氣風發
# 意欲主宰
# 意義非凡
# 意義重大
# 意趣
# 意謂
# 意謂著
# 意識
# 意識到
# 意願
# 慈和
# 慈祥
# 慈悲
# 慈悲心
# 慈悲為懷
# 慈善
# 慈愛
# 感人
# 感化
# 感同身受
# 感到心安
# 感到安慰
# 感到放心
# 感到高興
# 感到滿足
# 感到滿意
# 感到慶幸
# 感性
# 感恩
# 感動
# 感動萬分
# 感慨萬千
# 感激
# 感興趣
# 感謝
# 感覺
# 感覺真好
# 想出辦法
# 想必
# 想見
# 想知道
# 想看
# 想要
# 想要看
# 想要得到
# 想要贏
# 想拿下
# 想拿到
# 想問
# 想從
# 想符合
# 想開一點
# 想當
# 想當第一
# 想過
# 想像
# 想像力
# 想盡辦法
# 想儘早
# 想謀求
# 想辦法
# 想幫助
# 想獲勝
# 想贏得
# 愛人
# 愛人如己
# 愛上
# 愛心
# 愛打趣
# 愛好
# 愛好和平
# 愛和關心
# 愛妾
# 愛妻
# 愛國
# 愛國心
# 愛情
# 愛惜
# 愛透了
# 愛說話
# 愛憐
# 愛撫
# 愛戴
# 愛護
# 愈打愈旺
# 愈有幫助
# 愈快愈好
# 愈見增長
# 愈來愈多
# 愈來愈有
# 愈來愈近
# 愈來愈長
# 愈來愈高
# 愈來愈接近
# 愈來愈盛
# 愈來愈關心
# 愈益增加
# 愈發
# 愈戰愈勇
# 愈顯激烈
# 慎重行事
# 慎重起見
# 慎重應處
# 慎審
# 慎慮
# 慎選
# 搭起
# 搬出
# 搜集
# 搶下
# 搶手
# 搶手貨
# 搶在
# 搶佔
# 搶到
# 搶得
# 搶得先機
# 搶得第一
# 搶得領先
# 搶救
# 搶眼
# 搶勝
# 搶搭
# 搶盡
# 搶盡了鋒頭
# 搶盡風采
# 搶盡鋒頭
# 搶購
# 搶購一空
# 搶購浪潮
# 敬老
# 敬佩
# 敬畏
# 敬畏有加
# 敬重
# 敬祝
# 敬愛
# 敬禮
# 新水平
# 新世紀
# 新出爐
# 新任
# 新成立
# 新而多元
# 新希望
# 新奇
# 新的紀元
# 新的選擇
# 新思維
# 新紀元
# 新紀元來臨
# 新重心
# 新重點
# 新面貌
# 新頁
# 新秩序
# 新商機
# 新統合
# 新創
# 新進展
# 新意
# 新嘗試
# 新增
# 新締定
# 新誕生
# 新銳
# 新興
# 新選擇
# 新鮮
# 新鮮事
# 新寵
# 暗助
# 暗暗稱許
# 暖呼呼
# 暖和
# 暖烘烘
# 暖意
# 會心
# 會心一笑
# 會以
# 會同
# 會在
# 會有
# 會更好
# 會見
# 會使
# 會服從
# 會挑戰
# 會是
# 會重視
# 會勘
# 會參加
# 會堅持
# 會將
# 會談
# 會親
# 會贏
# 會顧及
# 會讓
# 業績最好
# 極力
# 極力主張
# 極力爭取
# 極力解決
# 極力誇獎
# 極可能
# 極正常
# 極好
# 極好的人
# 極有
# 極有可能
# 極有潛力
# 極有機會
# 極佳
# 極佳耐性
# 極具
# 極具雄心
# 極其顯著
# 極易
# 極度高興
# 極為
# 極為明顯
# 極為勇敢
# 極為高昂
# 極為密切
# 極為感動
# 極為慎重
# 極為熟悉
# 極為龐大
# 極為穩健
# 極為關切
# 極重要
# 極高
# 極強
# 極欲
# 極富彈性
# 極貴重
# 極感興趣
# 極需要
# 極樂
# 極點
# 極願
# 源源不絕
# 源源不斷
# 溝通協調
# 溫文
# 溫文儒雅
# 溫良
# 溫和
# 溫柔
# 溫柔親切
# 溫情
# 溫順
# 溫暖
# 溫慰
# 溫藹
# 溫馨
# 準備以
# 準備充分
# 準備好
# 準備迎接
# 準備參加
# 準備開始
# 準備達成交易
# 準確
# 煙消雲散
# 照例
# 照常
# 照常流通
# 照理
# 照理說
# 照護
# 照顧
# 煥發
# 當下
# 當上
# 當心
# 當世第一
# 當以
# 當成
# 當成英雄
# 當作
# 當你落後
# 當言
# 當省則省
# 當紅
# 當紅炸子雞
# 當面溝通
# 當家
# 當做
# 當務之急
# 當推
# 當然
# 當然好
# 當然更美
# 當然是
# 當然會
# 當然會好
# 當然歡迎
# 當道
# 當選
# 痴心
# 痴狂
# 痴情
# 痴痴
# 盟友
# 盟主
# 督促
# 督導
# 碰上
# 萬人迷
# 萬全
# 萬臣朝服
# 萬事具備
# 萬事順遂
# 萬能
# 萬歲
# 萬靈仙丹
# 稚齡
# 節制
# 節奏
# 節省
# 節約
# 節約能源
# 節儉
# 節慶
# 經回火後具有的韌度
# 經典
# 經典作
# 經常
# 經常想
# 經得起檢驗
# 經過
# 經過評估
# 經過學習
# 經調查
# 經濟成長
# 經濟復甦
# 經濟榮面
# 經濟繁榮
# 經營
# 經營佈置
# 經驗老到
# 經驗球
# 經驗豐富
# 置喙
# 義不容辭
# 義正詞嚴
# 義氣
# 義務
# 義無反顧
# 羨煞
# 群起仿效
# 群起效之
# 群策群力
# 聖人
# 聖子
# 聖河
# 聖徒
# 聖潔
# 聖誕禮物
# 腳步再快
# 腦力激盪
# 落入手中
# 落實
# 落實了
# 落實回饋
# 落實具現
# 落實執行
# 落實推動
# 落實照顧
# 號召
# 號稱
# 蛻變
# 蜂湧前來
# 蜂擁
# 補足
# 補強
# 補救
# 補給
# 補進
# 補實
# 補憾有餘
# 解危
# 解決了
# 解決能力
# 解凍
# 解除武裝
# 解答
# 解開
# 解開了
# 解禁
# 解讀
# 解讀為
# 該用則用
# 該有
# 該言
# 該言當言
# 該怎麼做就怎麼做
# 該是
# 詳加說明
# 詳述
# 詳細
# 詳盡
# 詳盡地
# 詳盡而合理
# 詳盡說明
# 試金石
# 試探
# 試著
# 試著實現
# 試圖利用
# 試圖說服
# 詩意
# 誇獎
# 誇讚
# 詼諧
# 誠心
# 誠心期盼
# 誠心誠意
# 誠如
# 誠信
# 誠盼
# 誠然
# 誠意
# 誠實
# 誠實以對
# 誠摯
# 誠摯的希望
# 誠懇
# 資助
# 資深
# 資深名將
# 資源
# 資源共享
# 資源豐富
# 資優
# 跟得上
# 跨出
# 跨出一大步
# 跨越
# 跨進
# 跨過
# 跳升
# 跳板
# 跳起舞來
# 跳脫
# 跳增
# 較大
# 較大進展
# 較划算
# 較好
# 較好者
# 較有利
# 較自由
# 較快
# 較佳
# 較具競爭力
# 較易
# 較易凸顯
# 較易著手
# 較明顯
# 較長
# 較為平坦
# 較為寬鬆
# 較高
# 較強
# 較優
# 較優者
# 較穩定
# 運用
# 運作順利
# 遊行
# 遊說
# 遊覽
# 道奇隊腿五項全能
# 道理
# 道喜
# 道賀
# 道歉賠償
# 道德
# 道德堅持
# 道德崇高
# 道德崇高的人
# 遂行
# 遂其所願
# 達共識
# 達多項共識
# 達成了
# 達成共識
# 達成多項共識
# 達成協議
# 達成和解
# 達成初步共識
# 達成突破
# 達成高度共識
# 達成統一
# 達成結論
# 達成默契
# 達此成就
# 達改革協議
# 達到一致
# 達到了
# 達到最高峰
# 達協議
# 達觀
# 逼出
# 逼到
# 逼真
# 逼真地
# 逼著
# 逼著了解
# 過人
# 過人球技
# 過招
# 過於強大
# 過高
# 過高期望
# 過頭關
# 過關斬將
# 過癮
# 鉅細靡遺
# 雋美
# 零缺點
# 預示
# 預估
# 預判
# 預見
# 預言
# 預定完成
# 預知
# 預計
# 預訂
# 預訂一空
# 預料
# 預留
# 預祝
# 預做準備
# 預售
# 預備
# 預期
# 預期揚升
# 預測
# 預謀
# 頓悟
# 頒布
# 頒發
# 頒給
# 頒獎
# 頌揚
# 頌德
# 頌讚
# 鼎力
# 鼎力支持
# 鼎足而立
# 鼎盛
# 鼓吹
# 鼓起勇氣
# 鼓掌
# 鼓掌致敬
# 鼓掌歡呼表示通過
# 鼓掌歡迎
# 鼓舞
# 鼓舞人心
# 鼓舞人心的人
# 鼓勵
# 鼓勵作用
# 煇煌
# 像個
# 像神一樣
# 僱用
# 兢兢業業
# 劃上等號
# 劃分
# 劃定
# 嘗到
# 嘗到和平
# 嘔心瀝血
# 嘉獎
# 嘖嘖稱奇
# 嘟嘟
# 團結
# 團結一致
# 團結合作
# 團圓
# 團聚
# 圖強
# 塵埃落定
# 夥伴關係
# 夢幻
# 夢想
# 夢想成真
# 奪三振
# 奪下冠軍
# 奪回
# 奪金
# 奪冠
# 奪得
# 奪得冠軍
# 奪得榜首
# 奪牌
# 奪銅
# 奪標
# 奪標有望
# 嫣然一笑
# 寧可選擇
# 寧靜
# 實力
# 實力相當
# 實力強
# 實力過人
# 實力證明
# 實力證明一切
# 實用
# 實用性
# 實地考察
# 實在
# 實在太好
# 實在是
# 實在論
# 實有必要
# 實至名歸
# 實事求是
# 實施
# 實為
# 實現了
# 實現出來
# 實話
# 實話實說
# 實際
# 實際上
# 實際可行
# 實際存在
# 實際協議
# 實質可信
# 實質作用
# 實質助益
# 察覺
# 對外散布
# 對外開放
# 對決勝出
# 對味
# 對等
# 對準
# 對照
# 屢敗屢戰
# 屢創佳績
# 嶄新
# 廓清
# 彰顯
# 徹厎
# 徹底
# 徹底打破
# 徹底並快速
# 徹底解決
# 慇懃
# 態度沈著
# 態度堅持
# 態度強硬
# 態度從容
# 態度懇切
# 慷慨
# 慷慨的行為
# 截然
# 摘下
# 摘取
# 摘金
# 撤軍
# 敲出
# 敲定
# 斡旋
# 旗開得勝
# 旗號
# 旗鼓相當
# 暢快
# 暢所欲言
# 暢旺
# 暢談
# 暢銷
# 榜首
# 榮光
# 榮幸
# 榮景
# 榮登
# 榮登寶座
# 榮銜
# 榮獲
# 榮膺
# 榮耀
# 榮譽
# 歌頌
# 演出
# 演出9K
# 演出完美
# 演出逆轉
# 滴水不漏
# 漂亮
# 漂亮地
# 漂亮的東西
# 漂亮摘下
# 漂漂亮亮
# 滿正常
# 滿足
# 滿面春風
# 滿健康
# 滿貫砲
# 滿貫彈
# 滿意
# 滿意地說
# 滿載
# 滿載而歸
# 滿滿
# 滿滿信心
# 滿臉微笑
# 滿壘全壘打
# 滿壘砲
# 滿懷
# 滿懷希望
# 滿懷信心
# 滿懷敬畏
# 漸入佳境
# 漸有起色
# 漸進
# 漸增
# 漸趨一致
# 漲至
# 漲幅
# 漲勢
# 澈底
# 滲透率高
# 甄選上
# 疑似
# 盡力
# 盡可能
# 盡全力
# 盡如人意
# 盡早
# 盡快
# 盡快公布
# 盡快平息
# 盡快解決
# 盡我所能
# 盡情
# 盡情地
# 盡速
# 盡最大努力
# 盡最大能力
# 盡量
# 盡量協助
# 盡量規避
# 盡歡
# 監督自治
# 監聽
# 瞄準
# 睿智
# 福利
# 福星高照
# 福祉
# 福音
# 種族和解
# 稱心
# 稱心如意
# 稱心快意
# 稱王
# 稱呼
# 稱冠
# 稱帝
# 稱為
# 稱做
# 稱得上
# 稱第一
# 稱許
# 稱雄
# 稱頌
# 稱頌讚嘆
# 稱職
# 稱霸
# 稱讚
# 窩心
# 竭誠
# 竭誠歡迎
# 竭盡所能
# 端正
# 端直
# 端莊
# 管制
# 算老大
# 算是
# 算數
# 箇中翹楚
# 精力
# 精力充沛
# 精力旺盛
# 精心
# 精心規劃
# 精心設計
# 精巧
# 精巧地
# 精巧的設計
# 精良
# 精芒閃現
# 精於預估
# 精明
# 精明幹練
# 精采
# 精采可期
# 精采表現
# 精采搶下
# 精采演出
# 精采戲碼
# 精美
# 精英
# 精神大振
# 精神支持
# 精神百倍
# 精純
# 精密
# 精彩
# 精彩演出
# 精細
# 精通
# 精減
# 精湛
# 精華
# 精進
# 精準
# 精確
# 精確性
# 精確度
# 精緻
# 精緻化
# 精選
# 精簡
# 精闢
# 精讀
# 精髓
# 綜合
# 綽綽有餘
# 緊守
# 緊盯
# 緊咬
# 緊急處理
# 緊要
# 緊要關頭
# 緊追
# 緊追不捨
# 緊追在後
# 緊追其後
# 緊密
# 緊張刺激
# 緊張降低
# 緊接
# 緊握
# 緊鑼密鼓
# 維持了
# 維持固定
# 維持秩序
# 維持現狀
# 維持穩定
# 維特
# 維護
# 維護人類健康
# 聞言大笑
# 肇於
# 臺灣省長宋楚瑜
# 與之匹敵
# 與之爭鋒
# 與日俱增
# 與日遽增
# 與有榮焉
# 與時並進
# 與時俱轉
# 與會
# 與賽
# 蓄勢
# 蓄勢待發
# 蒙受利益
# 蓋世
# 蒐集
# 蒐集完全
# 蒐證鑑識
# 製造雙殺
# 語驚四座
# 認可
# 認定
# 認為
# 認為是
# 認為應
# 認真
# 認真追求
# 誓約
# 誓師
# 誓牽成
# 說到做到
# 說明了
# 說服
# 說服力
# 說得好
# 說得過去
# 誘人
# 誘使
# 豪勇
# 豪爽
# 豪華
# 賓主盡歡
# 赫然可見
# 趕快
# 趕到
# 趕緊
# 輔助
# 輔導
# 輕而易舉
# 輕快
# 輕快地
# 輕易
# 輕易移動
# 輕易超過
# 輕捷
# 輕輕鬆鬆
# 輕騎
# 輕騎晉級
# 輕騎過關
# 輕鬆自在
# 輕鬆改寫
# 輕鬆抱走
# 輕鬆封王
# 輕鬆挺進
# 輕鬆晉
# 輕鬆晉級
# 輕鬆捧走
# 輕鬆獲勝
# 輕鬆闖關
# 辣妹
# 遠大於
# 遠大過
# 遠見
# 遠征
# 遠景
# 遠景看好
# 遠景樂觀
# 遠超過
# 遠較
# 遠遠甩開
# 遠遠超過
# 遠觀
# 遣返
# 遣送
# 遙遙甩開
# 遙遙領先
# 遞補
# 遞增
# 銅牆鐵壁
# 銘心
# 需及早
# 需求
# 需求大增
# 需求殷切
# 頗力
# 頗多
# 頗有可為
# 頗有好處
# 頗有改進
# 頗有淵源
# 頗佳
# 頗具
# 頗具吸引力
# 頗受重視
# 頗為強勢
# 頗為符合
# 頗為熱中
# 頗值
# 頗高
# 領出
# 領先
# 領先地位
# 領先者
# 領先最多
# 領先群雄
# 領先維特
# 領先優勢
# 領回
# 領取
# 領軍
# 領風騷
# 領航
# 領教
# 領袖
# 領銜
# 領獎
# 領導
# 領導者地位
# 鳴金收兵
# 齊心面對
# 齊名
# 齊揚
# 齊聚
# 齊聚一堂
# 蜚聲
# 蜚聲國際
# 儀態高貴
# 價廉
# 嘻嘻
# 嘻嘻哈哈
# 嘿嘿
# 增一倍
# 增加
# 增加互信
# 增加共識
# 增加免疫力
# 增列
# 增至
# 增長
# 增長了
# 增建
# 增為
# 增訂
# 增修
# 增強
# 增強免疫力
# 增添
# 增添了
# 增添更多
# 增添許多
# 增設
# 增幅
# 增援
# 增進
# 增進互信
# 增進友誼
# 嬉戲
# 嫻雅
# 嬌小
# 嬌美
# 寬大
# 寬心
# 寬厚
# 寬容
# 寬容風度
# 寬赦
# 寬敞
# 寬裕
# 寬達
# 寬廣
# 寬闊
# 寬鬆
# 審查完成
# 審查通過
# 審查過關
# 審慎
# 審慎以對
# 審慎密集
# 審慎處置
# 審閱
# 審議完成
# 寫入歷史
# 寫下
# 寫定
# 寫實
# 寫實地
# 廢寢忘食
# 廣大
# 廣大胸襟
# 廣受矚目
# 廣泛
# 廣泛採用
# 廣泛開放
# 廣為宣傳
# 廣為散布
# 廣設
# 廣播
# 廣邀
# 廣闊
# 彈性
# 彈性空間
# 德高望重
# 德高望重的人
# 徵用
# 徵詢
# 徵詢調查
# 慶幸
# 慶祝
# 慶賀
# 慰助
# 慰勉
# 慰問
# 慰問金
# 憧憬
# 憐恤
# 憐惜
# 憐憫
# 憐憫心
# 戮力以赴
# 戮力於
# 摩拳擦掌
# 撐下去
# 撐完
# 撐到
# 撐得過去
# 撐腰
# 撐腰壯聲勢
# 撥給
# 撥雲見日
# 撫平
# 數一數二
# 數以千計
# 數量優勢
# 暫定
# 暫居首席
# 暫居領先
# 暫時保留
# 樣樣精通
# 樞紐
# 標致
# 標榜
# 標識
# 模範
# 模範生
# 模擬
# 樂子
# 樂不可支
# 樂天
# 樂乎
# 樂在其中
# 樂此不疲
# 樂而忘憂
# 樂見
# 樂見其成
# 樂事
# 樂事多
# 樂呵呵
# 樂於
# 樂於接受
# 樂透
# 樂透了
# 樂園
# 樂意
# 樂意地
# 樂意接受
# 樂趣
# 樂翻
# 樂翻了
# 樂翻天
# 樂壞
# 樂觀
# 樂觀地
# 樂觀些
# 樂觀其成
# 樂觀的預期
# 樂觀開朗
# 毅力
# 毅然
# 潔淨
# 潛力大
# 潛心
# 潛心於
# 潮流所趨
# 澎湃
# 熟悉
# 熟慮
# 熟練
# 熟練地
# 熟練掌握
# 熱力
# 熱中
# 熱切
# 熱切地
# 熱切於
# 熱切盼望
# 熱切推動
# 熱心
# 熱心反菸害
# 熱心助人
# 熱心腸
# 熱忱
# 熱門
# 熱門商品
# 熱門話題
# 熱烈
# 熱烈討論
# 熱烈期待
# 熱烈歡迎
# 熱衷
# 熱得發燙
# 熱情的接待
# 熱情參與
# 熱情款待
# 熱望
# 熱絡
# 熱愛
# 熱誠
# 熱誠地
# 熱潮
# 熱熱鬧鬧
# 熱賣
# 熱鬧
# 熱鬧滾滾
# 熱戀
# 獎金
# 獎品
# 獎章
# 獎勵
# 璀璨
# 盤踞
# 磋商
# 磋商和解
# 確切
# 確可
# 確在擴展
# 確有
# 確有必要
# 確有此事
# 確有其事
# 確定
# 確定性
# 確定參賽
# 確知
# 確信
# 確保和平
# 確保繁榮
# 確是
# 確是很棒
# 確為
# 確曾
# 確實
# 確實有
# 確實是
# 確實符合
# 確認同意
# 確屬
# 窮本究源之道
# 範型
# 締交
# 締定
# 締造
# 締造利多
# 締造者
# 締造歷史
# 締創
# 締結
# 練成
# 緬懷
# 緩升
# 緩解
# 緩衝
# 緩衝期
# 翩翩
# 膜拜
# 蔚為風潮
# 蓬勃
# 蓬勃發展
# 衛生
# 衛冕
# 衛冕成功
# 衝上
# 衝上第一
# 衝向
# 衝刺
# 衝到
# 衝往
# 衝勁
# 衝破
# 衝鋒
# 褒多於貶
# 褒揚
# 談及
# 談成
# 談妥
# 談笑
# 談笑用兵
# 談笑風生
# 談戀愛
# 請示
# 請求
# 請求支援
# 請命
# 請益
# 請託
# 請教
# 請願
# 課徵
# 調升
# 調和
# 調查
# 調查鑑定
# 調派
# 調高
# 調停
# 調漲
# 調劑
# 調整
# 調整支應
# 調整完成
# 調整修正
# 調整劃歸
# 誰與爭鋒
# 論斷
# 豎白旗
# 豎起
# 豎起了白旗
# 賠到底
# 賞心悅目
# 賞對手
# 賞識
# 賞識到
# 賦予
# 賦予重任
# 賦予維持
# 賢人
# 賢君
# 賢明
# 賢淑
# 賢慧
# 賣力
# 賜予
# 質樸
# 趣味
# 趣味相同
# 踏上
# 踏出
# 踏出的一大步
# 踏出第一步
# 踏進
# 踏實
# 輝映
# 輝煌
# 輝煌落幕
# 輝耀
# 輪迴重生
# 適才適性
# 適切
# 適任
# 適合
# 適宜
# 適性
# 適度
# 適時
# 適時進場干預
# 適得
# 適得其所
# 適逢
# 適量
# 適意
# 適當
# 適當地
# 適當時機
# 適應
# 適應新挑戰
# 鄭重
# 醉人
# 醉心
# 銷售
# 銷售極佳
# 銷售熱潮
# 震懾
# 靠近
# 靠著
# 靠攏
# 鞏固
# 養好
# 養活
# 養顏美容
# 餘威
# 駐足
# 魅力
# 熠熠群星
# 舖路
# 儒雅
# 儘可能
# 儘快
# 儘快完成
# 儘快展開
# 儘快推動
# 儘快解決
# 儘快實施
# 儘速
# 儘速化解
# 儘速完成
# 儘速展開
# 儘速推動
# 儘速通過
# 儘速給付
# 儘速確定
# 儘量
# 儘量加強
# 儘量使用
# 冀望為
# 凝合力
# 凝聚
# 凝聚共識
# 凝聚性
# 勳章
# 勳績
# 噪聲小
# 器重
# 奮力
# 奮力一擊
# 奮力掙扎
# 奮力演出
# 奮不顧身
# 奮爭
# 奮勇
# 奮起
# 奮鬥
# 奮發
# 奮進
# 學以致用
# 學好
# 學成
# 學成歸國
# 學有專精
# 學習好
# 學進
# 學進去
# 學會謙卑
# 導入
# 導正
# 導向
# 憑著
# 戰力
# 戰利品
# 戰技精良
# 戰勝
# 戰無不勝
# 戰績佳
# 戰績輝煌
# 戰績獨走
# 擅於
# 擅長
# 擁抱
# 擁護
# 擁護者
# 據以下令
# 據以制訂
# 據以論斷
# 據以斷定
# 據以證明
# 據此
# 據估計
# 據信
# 據推測
# 據理力爭
# 據實
# 據實反映
# 據實以告
# 據稱
# 據說
# 擄獲
# 擇吉
# 擇優
# 操作得當
# 操持
# 操控
# 操盤
# 撿到便宜
# 撿便宜
# 擔任
# 擔待
# 擔綱
# 整合
# 整合成功
# 整治
# 整建
# 整理出來
# 整頓
# 整齊
# 整潔
# 整體而言
# 樸素
# 橫掃
# 橫掃千軍
# 樹立
# 機動性大
# 機動性最大
# 機敏
# 機敏地
# 機率很高
# 機智
# 機會
# 機警
# 機靈
# 歷久不衰
# 歷史性
# 歷史最久
# 歷史新高
# 歷來僅見
# 歷經
# 濃厚
# 濃情蜜意
# 澤及
# 澤及後人
# 激列
# 激昂
# 激發
# 激發支持
# 激增
# 激賞
# 激奮
# 激勵
# 激勵作用
# 激盪
# 燃起希望
# 獨一無二
# 獨力推動
# 獨大
# 獨占第一
# 獨占鰲頭
# 獨立
# 獨立自主
# 獨有
# 獨步
# 獨步全球
# 獨享
# 獨居
# 獨居首席
# 獨居領先
# 獨特
# 獨特魅力
# 獨強
# 獨得
# 獨創
# 獨創性
# 獨尊
# 獨領
# 獨領世界風騷
# 獨領風騷
# 獨贏
# 獨霸一方
# 磨刀霍霍
# 磨功
# 磨好利爪
# 積極
# 積極支持
# 積極支援
# 積極主動
# 積極任事
# 積極因應
# 積極回應
# 積極性
# 積極要求
# 積極革新
# 積極務實
# 積極參與
# 積極推展
# 積極推動
# 積極尋
# 積極尋求
# 積極尋求改善
# 積極發展
# 積極開拓
# 積極搶攻
# 積極準備
# 積極輔導
# 積極辦理
# 積極擬定
# 積極擴大
# 積德
# 窺見
# 篤定
# 篤定加冕
# 篤定成為
# 翱翔
# 興沖沖
# 興旺
# 興建
# 興致勃勃
# 興起
# 興高采烈
# 興高采烈地
# 興盛
# 興隆
# 興奮
# 興奮不已
# 興奮期待
# 融入
# 融化
# 融合
# 融和
# 融洽
# 親切
# 親自
# 親自下達
# 親自主持
# 親自出馬
# 親自目睹
# 親自迎接
# 親自前往
# 親自陪同
# 親自督軍
# 親自歡迎
# 親身指導
# 親和
# 親迎
# 親近
# 親信
# 親密
# 親善
# 親愛
# 謀求
# 謀求改善
# 謀求統一
# 謀求解決
# 謀定
# 諾言
# 踴躍
# 踴躍加入
# 踴躍異常
# 辨明
# 辨認
# 辨識
# 辦到
# 遵行
# 遵從
# 遴選
# 選出
# 選用
# 選定
# 選拔
# 選擇和平
# 選擇購買
# 遺留
# 醒目
# 錯不在
# 鋼人
# 錄取
# 錦上添花
# 錦囊妙計
# 隨之改變
# 隨心所欲
# 隨即
# 隨時可以
# 險勝
# 靜定
# 頻傳
# 頻頻點頭
# 頭條
# 頭腦清楚
# 頭號
# 頭銜
# 鴨霸
# 默許
# 默禱
# 龍爭虎鬥
# 龍飛鳳舞
# 龍頭老大
# 憨厚
# 優化
# 優先
# 優先考量
# 優先於
# 優先保障
# 優先要求
# 優秀
# 優秀人才
# 優良
# 優於
# 優哉遊哉
# 優美
# 優美地
# 優異
# 優異成績
# 優異表現
# 優勝
# 優惠
# 優游
# 優渥
# 優越感
# 優雅
# 優勢
# 優裕
# 優質
# 優點
# 償清
# 儲備
# 勵學
# 嚐到甜頭
# 壓倒性勝利
# 幫了
# 幫了很大的忙
# 幫手
# 幫他
# 幫忙很大
# 幫助更大
# 幫助甚大
# 幫助脫離困境
# 彌合
# 彌足
# 彌足珍貴
# 彌補了
# 應予
# 應予肯定
# 應予尊重
# 應比照
# 應以
# 應加快
# 應加快腳步
# 應加強
# 應可
# 應可以
# 應可思考
# 應可望
# 應用
# 應用最廣
# 應由
# 應先
# 應先解決
# 應同
# 應向
# 應有
# 應有權益
# 應考慮
# 應把
# 應把握機會
# 應更強硬
# 應沒有問題
# 應享有
# 應依
# 應協助
# 應拋棄
# 應於
# 應爭取
# 應肩負
# 應保留
# 應促
# 應思考
# 應按
# 應持有
# 應是
# 應是如此
# 應是相當明顯
# 應為
# 應致力
# 應負
# 應重視
# 應准
# 應能
# 應配合
# 應做
# 應做到
# 應堅持
# 應將
# 應得
# 應從
# 應接不暇
# 應採取
# 應尊重
# 應循
# 應提出
# 應發揮
# 應等於
# 應給予
# 應善用
# 應趁
# 應會
# 應當
# 應當感謝
# 應解決
# 應該
# 應該了解
# 應該加速進行
# 應該可以
# 應該同意
# 應該信守
# 應該是
# 應該相信
# 應該要
# 應該堅持
# 應該會
# 應該獲得保障
# 應構築
# 應盡
# 應盡量
# 應增加
# 應徵詢
# 應調整
# 應賠償
# 應儘快取
# 應儘速
# 應戰
# 應積極對外宣示
# 應遵守
# 應遵行
# 應遵重
# 應優先執行
# 應檢討
# 應獲
# 應獲得
# 應聯手
# 應避免
# 應邀回訪
# 應邀前往
# 應歸功
# 應藉
# 應謹慎行事
# 應繼續
# 應屬
# 應屬合理
# 應變
# 應驗
# 懂事
# 懂得
# 懇切
# 懇切溝通
# 懇求
# 懇摯
# 懇請
# 戲劇性
# 擊出
# 擊敗群雄
# 擘畫
# 擠上
# 擠得上
# 擠得上榜
# 擠滿了
# 擬出
# 擬妥
# 擬定
# 擬議
# 檢視
# 濟事
# 濟濟
# 營收
# 營救
# 營造
# 營養
# 燦爛
# 獲力
# 獲任命
# 獲共識
# 獲好評
# 獲此殊榮
# 獲判
# 獲利
# 獲利了解
# 獲批准
# 獲取
# 獲取好處
# 獲知
# 獲保送
# 獲冠
# 獲致
# 獲致共識
# 獲致利益
# 獲致重要共識
# 獲准
# 獲殊榮
# 獲益
# 獲益仍是良多
# 獲益匪淺
# 獲得共識
# 獲得好處
# 獲得成果
# 獲得改善
# 獲得具體共識
# 獲得承認
# 獲得肯定
# 獲得初步共識
# 獲得保障
# 獲得冠軍
# 獲得突破
# 獲得重視
# 獲得勝利
# 獲得勝選
# 獲得喘息
# 獲得援助
# 獲得解決
# 獲得滿足
# 獲得澄清
# 獲得遵行
# 獲得證明
# 獲得證實
# 獲悉
# 獲救
# 獲勝
# 獲勝投
# 獲提名
# 獲評
# 獲過
# 獲頒
# 獲獎
# 獲獎金
# 獲賠
# 獲賠償
# 獲選
# 獲選為
# 獲償
# 獲邀
# 獲邀參賽
# 獲邀請
# 獲釋
# 環境保護
# 療傷
# 瞭解
# 矯正
# 矯治
# 績效
# 績效良好
# 總冠軍
# 總是
# 總該
# 縱橫
# 繁茂
# 繁盛
# 繁榮
# 繁榮發展
# 繁榮進步
# 繁榮興盛
# 聲名大噪
# 聲明
# 聲浪鼎沸
# 聲望
# 聲勢
# 聲勢浩大
# 聲稱
# 聲請
# 聲譽
# 聲譽好
# 聲譽良好
# 聰明
# 聰慧
# 聰穎
# 聯手
# 聯手出擊
# 聯手修正
# 聯手贏得
# 聯合
# 聯合主辦
# 聯合拓展
# 聯合服務
# 聯合宣言
# 聯合起來
# 聯合提議
# 聯合聲明
# 聯絡
# 聯盟第一
# 膺殊榮
# 膺選
# 膽量
# 臉紅
# 臨危不亂
# 臨門一腳
# 舉世所矚目
# 舉世聞名
# 舉世讚譽
# 舉行
# 舉行凱旋式
# 舉足輕重
# 舉國歡騰
# 舉辦
# 舉雙手贊成
# 舉證
# 襄佐
# 襄助
# 襄理
# 謙卑
# 謙和
# 謙恭
# 謙恭有禮
# 謙恭有禮的言辭
# 謙虛為懷
# 謙遜
# 謙遜地
# 講求
# 講究
# 講義氣
# 謝天謝地
# 謝意
# 謝謝
# 豁免
# 豁然
# 豁然開朗
# 賺了
# 賺入甚多
# 賺到
# 賺進
# 賽史最多
# 賽史新猷
# 購入
# 購併
# 購併風潮
# 購買
# 趨向
# 趨於
# 趨於走緩
# 趨於緩和
# 趨近
# 趨堅
# 趨強
# 輿薪
# 避免傷及
# 避風港
# 避戰
# 避險
# 避險功效
# 遽下判斷
# 還可
# 還可以
# 還好
# 還有
# 還有可能
# 還是
# 還是需要
# 還要
# 還能
# 還高
# 還將
# 還須
# 還會
# 還會再出現
# 還會有
# 還算
# 還算是
# 還需
# 邁入
# 邁出
# 邁出一步
# 邁向
# 邁向目標
# 邁向和平
# 邁向和解
# 邁向展開
# 邁向新的紀元
# 邁向新高
# 邁步
# 邁進
# 邁進一大步
# 邁開
# 邁開大步
# 邀約
# 邀集
# 醞釀
# 鍥而不捨
# 鍾情
# 鍛煉
# 隱約露出
# 雖敗猶榮
# 鮮明
# 鮮明印象
# 鮮明展現
# 鮮麗
# 鮮豔
# 鴻通
# 點明燈
# 點頭
# 嚮往
# 擴大共識
# 擴大吸引外資
# 擴大適用
# 擴大辦理
# 擴充
# 擴建
# 擴展
# 擴增
# 擴權
# 擺好定石
# 擺明
# 擺脫低潮
# 擺脫長期聯招夢魘
# 斷言
# 斷定
# 歸功
# 歸功於
# 歸於
# 歸納
# 歸責
# 歸諸
# 歸屬
# 獵下
# 獵獲
# 禮盒
# 禮貌
# 禮儀
# 竄升
# 簡易
# 簡明
# 簡便
# 簡單
# 簡樸
# 織補
# 翹首以盼
# 翹楚
# 翻身
# 職責
# 職業精
# 藍天
# 藉以
# 藉以加速
# 藉由
# 蟬連
# 蟬聯
# 謹言慎行
# 謹記
# 謹記在心
# 謹慎
# 謹慎行事
# 豐功偉績
# 豐收
# 豐盈
# 豐富
# 豐腴
# 豐實
# 豐滿
# 豐碩
# 豐饒
# 轉化人心
# 轉向
# 轉好
# 轉捩點
# 轉移
# 轉換
# 轉機
# 轉圜
# 轉圜的餘地
# 轉圜餘地
# 轉趨熱絡
# 鎖定
# 鎮定
# 鎮鎮定定
# 闖一關
# 闖出一片天
# 闖越過
# 闖過一關
# 闖過這關
# 闖過頭關
# 闖蕩
# 闖頭關
# 闖關
# 雙強
# 雙殺打
# 雙喜臨門
# 雙管齊下
# 雙蒙其利
# 雙贏
# 雙響砲
# 額度大
# 鬆一口氣
# 寵兒
# 寵幸
# 寵愛
# 懷有
# 懷有憧憬
# 懷念
# 懷抱信心
# 懷著
# 懷著希望
# 攀上
# 攀高
# 瀟洒
# 瀟灑
# 爆升
# 爆發力
# 爆滿
# 癡情
# 穩住
# 穩住了
# 穩住江山
# 穩住陣腳
# 穩佔上風
# 穩坐
# 穩妥
# 穩妥地
# 穩步上揚
# 穩固
# 穩定
# 穩定地
# 穩定性
# 穩定貨幣
# 穩定發展
# 穩定經濟
# 穩居
# 穩重
# 穩健
# 穩健冷靜
# 穩紮穩打
# 穩當
# 簽下
# 簽定
# 簽約
# 簽訂
# 簽准
# 簽署
# 簽署定案
# 簽署誓約
# 繫於
# 繳交
# 證言
# 證明
# 證明了
# 證詞
# 證實
# 證實無誤
# 證諸
# 證據
# 證據顯示
# 贈送
# 贊同
# 贊同之意
# 贊成
# 贊成的一方
# 贊成的論點
# 贊成者
# 贊成票
# 贊助
# 贊許
# 關切
# 關係密切
# 關連
# 關進
# 關愛
# 關愛參與
# 關鍵
# 關鍵因素
# 關鍵角色
# 關鍵性
# 關懷
# 難以偵知
# 難以勝數
# 難忘
# 難怪
# 難得一見
# 難得機會
# 韻味
# 類似
# 願予
# 願支援
# 願望
# 願提供
# 願景
# 願意合作
# 願意配合
# 願意參加
# 願意接受
# 勸進
# 勸說
# 勸慰
# 勸導
# 嚴正立場
# 嚴格把關
# 嚴格要求
# 嚴格遵守
# 嚴密
# 嚴密掌控
# 嚴肅認真
# 嚴謹
# 嚴謹把關
# 寶刀磨利
# 寶座
# 寶貴
# 攔截到
# 攙扶
# 獻上
# 競合產生
# 競爭力
# 競爭力強
# 競爭加大
# 競爭能力
# 競爭優勢
# 競爭壓力
# 競相
# 競相持有
# 競逐
# 競逐殊榮
# 籌建
# 籌設
# 籌備
# 籌畫
# 籌辦
# 繽紛
# 繼承
# 繼起
# 繼績
# 繼續
# 繼續交涉
# 繼續存在
# 繼續努力
# 繼續依照
# 繼續協商
# 繼續保持
# 繼續留用
# 繼續堅持
# 繼續執行
# 繼續強調
# 繼續推動
# 繼續處理
# 繼續貫徹
# 繼續發生
# 繼續發揮
# 繼續發酵
# 繼續進行
# 繼續開放
# 繼續維持
# 繼續增強
# 繼續調查
# 繼續適用
# 繼續擔任
# 繼續攀升
# 耀眼
# 蘊含
# 覺悟
# 覺得
# 覺察
# 覺醒
# 觸角
# 觸底反彈
# 議決
# 警戒心
# 警醒
# 警覺
# 警鐘
# 贏了
# 贏了面子
# 贏回
# 贏足
# 贏來
# 贏取
# 贏定
# 贏定了
# 贏面
# 贏家
# 贏得
# 贏得好彩頭
# 贏得冠軍
# 贏得殊榮
# 贏得勝利
# 贏得輕鬆
# 贏得驚險
# 贏球
# 贏過
# 贏過球
# 贏錢
# 釋出
# 釋放
# 釋懷
# 闡明
# 闡述
# 飄揚
# 饒富意義
# 騰躍
# 屬於
# 屬實
# 攜手打拚
# 攜手共策
# 攜手合作
# 攜回
# 攜帶
# 灌進
# 續向
# 續有進展
# 續居
# 續約
# 續聘
# 續寫
# 護主
# 護主力辯
# 護佑
# 護持
# 護送
# 護衛
# 譽為
# 躍入
# 躍上
# 躍上首席
# 躍升
# 躍升為
# 躍居
# 躍居領先
# 躍居樞紐
# 躍進
# 躍躍欲試
# 躋身
# 躋身逐冠
# 轟出安打
# 轟到
# 轟動
# 鐵了心
# 鐵血三娘子
# 鐵定
# 鐵定是
# 鐵律
# 鐵娘子
# 鐵證如山
# 闢出
# 霸天
# 霸占
# 霸業
# 霸賞
# 露出
# 露出微笑
# 露出端倪
# 露臉
# 顧及
# 顧慮周到
# 驅力
# 驅策
# 魔力
# 魔法
# 礭實
# 飆出
# 囊括
# 巔峰
# 懿美
# 權力
# 權力平衡
# 權大勢大
# 權威
# 權威性
# 權益
# 權傾天下
# 歡天喜地
# 歡呼
# 歡欣
# 歡欣鼓舞
# 歡迎
# 歡迎參加
# 歡迎進行
# 歡迎調查
# 歡喜
# 歡愉
# 歡愉地
# 歡慶
# 歡慶勝利
# 歡樂
# 歡聲雷動
# 歡騰
# 歡躍
# 歡歡喜喜
# 聽取
# 聽命行事
# 聽從
# 聽話
# 聽說
# 讀出
# 贖回
# 贖罪
# 鑑別力
# 鑑定
# 鑑於
# 驕傲於
# 戀愛
# 戀戀
# 纖細
# 變大
# 變平靜
# 變好
# 變更
# 變乖
# 變法圖強
# 變得
# 變得較好
# 變清
# 變新
# 邏輯
# 顯示出
# 顯而易見
# 顯見
# 顯明
# 顯得
# 顯得容易
# 顯現
# 顯現了
# 顯然是
# 顯著
# 顯著地
# 顯著提升
# 顯著提高
# 顯著增加
# 顯著激增
# 顯著優於
# 顯赫
# 顯屬
# 驚人氣勢
# 驚人潛力
# 驚人魅力
# 驚奇
# 驚為神童
# 驚喜
# 驚羨
# 驚險晉級
# 驚險過關
# 驚險摘冠
# 驚險獲勝
# 驚艷
# 驚讚
# 體壯
# 體格壯碩
# 體現
# 體貼
# 體會
# 體察
# 體認
# 體認到
# 體諒
# 體質不錯
# 體質健康
# 體質強健
# 體壇巨星
# 體積大為縮減
# 讓人印象深刻
# 讓人信服
# 讓人動容
# 讓人感動
# 讓人難忘
# 讓出
# 艷麗
# 靈巧
# 靈巧地
# 靈光
# 靈妙
# 靈活
# 靈活運用
# 靈敏
# 靈敏性
# 靈魂人物
# 驟升
# 驟得盛名
# 蠻幹到底
# 觀念
# 觀察
# 觀賞
# 矚目
# 讚不絕口
# 讚好
# 讚許
# 讚許有加
# 讚揚
# 讚頌
# 讚歎
# 讚歎不已
# 讚賞
# 讚賞有加
# 讚譽
# 讚譽有加
# 籲求
# 籲請
