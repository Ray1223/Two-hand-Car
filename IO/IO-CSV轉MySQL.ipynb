# %%
import pymysql
import pandas as pd
import sys
import xlrd
import pandas
df= pandas.read_excel("C:\\Users\\BIG DATA\\Desktop\\analysis\\C50\\C50_0728.xlsx",encoding = "utf-8")
carGroup = []
url = []
for idx in df['url']:
    url.append(idx)
# print(url)
for idx in df['carGroup']:
    carGroup.append(idx)
# print(carGroup)
a = zip(carGroup,url)
# for idx in a :
#     print(idx[0],idx[1])
    
# pandas.merge(df['url'],df['carGroup'])

# %%
table
# Out:
#       index  Series       brand  brand_N           model  years  \
# 0       378       0  VOLKSWAGEN        2           VENTO   2016
# 1       380       0  VOLKSWAGEN        2           VENTO   2016
# 2       381       0  VOLKSWAGEN        2           VENTO   2016
# 3       384       0  VOLKSWAGEN        2       SPORTSVAN   2016
# 4       385       0  VOLKSWAGEN        2       SPORTSVAN   2016
# 5       386       0  VOLKSWAGEN        2         TOUAREG   2016
# 6       387       0  VOLKSWAGEN        2       SPORTSVAN   2016
# 7       388       0  VOLKSWAGEN        2         TOUAREG   2016
# 8       389       0  VOLKSWAGEN        2          TOURAN   2016
# 9       390       0  VOLKSWAGEN        2          TOURAN   2016
# 10      391       0  VOLKSWAGEN        2          TIGUAN   2016
# 11      392       0  VOLKSWAGEN        2          TOURAN   2016
# 12      393       0  VOLKSWAGEN        2          TIGUAN   2016
# 13      394       0  VOLKSWAGEN        2            POLO   2016
# ...

# %%
IP = '192.168.196.36'
passwd = 'team1'
    
conn = pymysql.connect(host=IP, port=3306, user='team1', passwd=passwd, db='team1',charset='utf8')
cur = conn.cursor()

count = 0   
try:
    for idx in a :
#         print(int(idx[0]),str(idx[1]))
#         cur.execute('UPDATE team1.newCar SET carGroup = %s WHERE url = %s;', [int(idx[0]),str(idx[1])])
        count +=1
        if count %10 ==0:
            print("There is {}th data".format(count))
        
except Exception as e:
    print("MySQL : ",e)
    conn.rollback()
conn.commit()
conn.close()
# Out:
# There is 10th data
# There is 20th data
# There is 30th data
# There is 40th data
# There is 50th data
# There is 60th data
# There is 70th data
# There is 80th data
# There is 90th data
# There is 100th data
# There is 110th data
# There is 120th data
# There is 130th data
# There is 140th data
# There is 150th data
# There is 160th data
# There is 170th data
# There is 180th data
# There is 190th data
# There is 200th data
# There is 210th data
# There is 220th data
# There is 230th data
# There is 240th data
# There is 250th data
# There is 260th data
# There is 270th data
# There is 280th data
# There is 290th data
# There is 300th data
# There is 310th data
# There is 320th data
# There is 330th data
# There is 340th data
# There is 350th data
# There is 360th data
# There is 370th data
# There is 380th data
# There is 390th data
# There is 400th data
# There is 410th data
# There is 420th data
# There is 430th data
# There is 440th data
# There is 450th data
# ...
